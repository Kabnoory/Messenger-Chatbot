# %%
import pandas as pd
import numpy as np
import os
import re
from datetime import datetime


def getData(path,personName):
	responseDictionary = dict()
	fbFile = open(path, 'r') 
	allLines = fbFile.readlines()
	myMessage, otherPersonsMessage, currentSpeaker = "","",""
	for index,lines in enumerate(allLines):
	    rightBracket = lines.find(']') + 2
	    justMessage = lines[rightBracket:]
	    colon = justMessage.find(':')
	    # Find messages that I sent
	    if (justMessage[:colon] == personName):
	        if not myMessage:
	            # Want to find the first message that I send (if I send multiple in a row)
	            startMessageIndex = index - 1
	        myMessage += justMessage[colon+2:]
	        
	    elif myMessage:
	        # Now go and see what message the other person sent by looking at previous messages
	        for counter in range(startMessageIndex, 0, -1):
	            currentLine = allLines[counter]
	            rightBracket = currentLine.find(']') + 2
	            justMessage = currentLine[rightBracket:]
	            colon = justMessage.find(':')
	            if not currentSpeaker:
	                # The first speaker not named me
	                currentSpeaker = justMessage[:colon]
	            elif (currentSpeaker != justMessage[:colon] and otherPersonsMessage):
	                # A different person started speaking, so now I know that the first person's message is done
	                otherPersonsMessage = cleanMessage(otherPersonsMessage)
	                myMessage = cleanMessage(myMessage)
	                responseDictionary[otherPersonsMessage] = myMessage
	                break
	            otherPersonsMessage = justMessage[colon+2:] + otherPersonsMessage
	        myMessage, otherPersonsMessage, currentSpeaker = "","",""    
	return responseDictionary


def cleanMessage(message):
	# Remove new lines within message
	cleanedMessage = message.replace('\n',' ').lower()
	# Deal with some weird tokens
	cleanedMessage = cleanedMessage.replace("\xc2\xa0", "")
	# Remove punctuation
	cleanedMessage = re.sub('([.,!?])','', cleanedMessage)
	# Remove multiple spaces in message
	cleanedMessage = re.sub(' +',' ', cleanedMessage)
	return cleanedMessage

# %%
personName = raw_input('Enter your full name: ')
# Out:
# Enter your full name: Mahmoud Ashraf Khairy

# %%
personName
# Out:
# 'Mahmoud Ashraf Khairy'

# %%
FacebookDictionary = {}
FacebookDictionary.update(getData('fbmessages.txt', personName))

# %%
FacebookDictionary
# Out:
# {'ok lemme know if she does ': "she still didn't answer lol ",
#  'no i dont at all that look the same ill see how it looks ill go shopping on thursday and in montreal theres a shopping mall right next to our hotel ill check there too ': 'it doesnt look good ',
#  "http://wwwfacebookcom/#/photophpfbid=10150601491482497&set=a16204695249611537763843132496&type=1&theater :'( 7asbanallah wan3mal wakiil ": 'ya3ny nezelty wala l2a 3shan ana mafhemtesh :/ ',
#  'ok ty babe ': 'do u miss ur gf ur crush ',
#  'yeaaa thats even here in waterloo and urrr da only africann ': 'yaaaaa whats good ma niggas ',
#  'ps -- ': 'aah :d wenty bete3mely eeh ',
#  'you cant transfer ': 'it takes a week to get from egypt i got 1 2 3 4 5 6 7 8 mill in my bank account ',
#  'thank you\xe2\x9d\xa4\xef\xb8\x8f i love you\xe2\x9d\xa4\xef\xb8\x8f ': 'love u more\xe2\x9d\xa4\xef\xb8\x8f\xe2\x9d\xa4\xef\xb8\x8f ',
#  "you're busyyy nooo ": "i'm not ",
#  'yo are we going to work on 146 tomorrow sorry i missed last time i felt so sick i just handed what i had from what i worked on 4 days before ': 'yeaa ofc stc again at night ',
#  '2day is the last day ': 'leeh ',
#  'and i am of youu\xe2\x9d\xa4\xef\xb8\x8f\xe2\x9d\xa4\xef\xb8\x8f how is your project goingg ': ' ',
#  'thats goodddd is it helping ': "they're just solving sample midterm ",
#  'please watch one episode only ': 'ok ',
#  'none in another ': 'which two ',
#  'haha i think mine is ': 'wait gay what bruh pink ties are the best ',
#  'didnt know its too much to ask for you to sit with me on my last days with you ': 'oh no every time i open youtube since i met u u cry ',
#  'know what ': "that u didn't mean ",
#  "i feel like you're speaking another language because i really dont get it what ": ' ',
#  'what does that showwww ': 'transfer why because she stupid ',
#  'thats what the gov does ': 'while architectures build buildings u build cities ',
#  'how does religion have anything to do with this ': 'if i talk about egypt u think about iran ',
#  "betgeeb wara2a ma5tooma mel gam3a ennak moqayyad w keda w betroo7 tetalla3 shahada 2 gond men el tagneed w troo7 makan esmo \xd8\xa7\xd9\x84\xd8\xa8\xd8\xb9\xd8\xab\xd8\xa7\xd8\xaa fi mogamma3 el ta7reer ba3d keda i think beterga3 tany el tagneed bas i haven't reached that step yet ": 'da el mawdoo3 da kolo bya5od ad eh ',
#  'ohhh guessing she came now hv fun bi ': "wattt r u studying y r u online show me what u finisheddddd u're not studying ",
#  'why are you stalking me bbgdd ': 'kont badalet sowar 3andy ml mobile la2ethaa di 3andek 3al facebook ',
#  "what do u mean {1} can't be a zero vector only {0} yeah vs4 is additive inverse vector space needs to have one ": "i mean when we add it to it's additive inverse for example {01} + {-10} = {-101} adding the additive inverse makes the set bigger not {0} i think ",
#  'i just came homeee ': 'homee post offiiceee ',
#  'thats not you i seen him enough in pics to know ': 'that is me ',
#  'what am i trying to cover i showed you who im with ': "tell me the truth i didn't say u were with guys ",
#  'salam w 3ayzk tkrwt kwisss ': ':d enta bas t2mor ',
#  'okay bye ': "bye hey i'm playing draw my thing right now come join me https://appsfacebookcom/drawmything/app_data=jfb%2f826009240&y=c&st2=fb&t=c20288c5 nora shofty ana nezelt el ta7rir ana mabsoot gedan :) ",
#  'wenta tayebb was reading about waterloo reddit machine learning and found your post haha https://wwwgoogleca/amp/s/ampredditcom/r/uwaterloo/comments/79iwxj/staying_in_cs_to_take_machine_learning_courses/ ': ' i post a lot of questions on there ',
#  'what are you watching ': 'lifeless ',
#  'only because of mama what will you do noww ': 'i wanted u to drop in dc but u ran ',
#  ' bs bageeb daragat we7sha ': 'a7a mafeesh moqarna aslan been el kont bazakro f ig w now ana bazaker keteer neek w bageeb 5ara gebt 25/50 f assignment linear algebra ',
#  'see its nothing ': '86 ',
#  "nice we'll ace it we learned so much in 145 ": 'nonononono i know nothing from 145 ',
#  'i just finished eating ': 'are u free now hasmig missed a call from you who are u talking to hasmig missed a call from you i think i said we need to talk at this time ',
#  'where r you bitches ': "i'll be there in 30 min if u guys are still therr ",
#  ' m2ltsh wehsh bs altly olilo y7la2o ': 'eh el araf da bas ',
#  'kiddnapping you ': ' do u have that in saudi no ',
#  'dude good luck ': "hey bro how did u prepare for 247 i read his notes yesterday and that's it i feel pretty unprepared lol ",
#  'you didnt find the sunscreennn ': 'no i dont want to spend tonight alone ',
#  "oh you're studying at home already ": "till i cook and eat and chill it's already 11 lol ",
#  'ahhh wentaa ': 'ahhh nezelt yomeen awel yomeen 30 w 1 wnty ',
#  'seems like i am ': "bas u should've expected i'd definitely say no w u know why without the discussion we didn't even discuss i just told u put urself in my shoes and u realized that u shouldn't ",
#  'you didnt say thattt or thatt ': 'that i was searching for ',
#  'pi kaa ': 'why do u know this information ni gaa ',
#  'sorryy noor woke upp ': 'from me ',
#  'me:))) ': "when we're sitting together ",
#  'i mean x in z ': "in (a) it's around x = 0 b it's around x = -1 ",
#  'hhahahhahha okay xd batzakrr eh i can help u ': "ba7el ss :'( bakrahoo korh el 3ama ",
#  'ah kont ba7sab xd haahahhahahahahahahahah xd anyway thx awiii for givin me the money :d ^_^ happy to know u ya mahmoud :p ': 'ana madetsh 7aga lesa ',
#  'home why ': 'byeeeee ',
#  'el7 7lwa shwaya ': 'mmm:) byee ',
#  'mmmm kkk shokran enta yabni ': 'aywa :d ',
#  'and you didnt need to get involved if you cannot take it anymore ': 'i have been trying to make u feel confident for so long ',
#  'how is that bullshit i didnt call anyone else i wasnt speaking to anyone else and havent called anyone else i closed and slept my reason for it sounds so stupid but its my reason ': "it's not ",
#  'do you know how it originated ': 'no ',
#  'bos hwa mlhash da3wa b ruf3 w kda ana ama atkhn batkhn mn regle fa shakl el pantalon kaka msh mushklaa sahl temzlhum tenzlhum gym w akl mzbuut bs ': "ahh 3'eer bas eny ba2aly sana sa7by by2oly nenzel el gym wanna a2olo bokra kasooll ",
#  '7drtk ana kont 7akalmoo w asawrlk el chat w tshoofi 7drtk da seliim ': '7drtk ',
#  'first impression ': 'idgaf ',
#  'and i write up every assignment in latex for 3 different math classes ': "damn why don't u just write it down with pencil it will save so much time ",
#  "you're proving that wrong you are smart ": "all mathematicians were bipolar yea smart not a genius bipolar disorder previously known as manic depression is a mental disorder that causes periods of depression and periods of elevated mood[2][3] the elevated mood is significant and is known as mania or hypomania depending on its severity or whether symptoms of psychosis are present during mania an individual behaves or feels abnormally energetic happy or irritable[2] individuals often make poorly thought out decisions with little regard to the consequences the need for sleep is usually reduced during manic phases[3] during periods of depression there may be crying a negative outlook on life and poor eye contact with others[2] the risk of suicide among those with the illness is high at greater than 6 percent over 20 years while self-harm occurs in 30\xe2\x80\x9340 percent[2] other mental health issues such as anxiety disorders and substance use disorder are commonly associated that's me right right right pls ",
#  "dont buy anything just send me pictures of something you see that you'd like me to wear and ill buy it later since you hate all my clothes ": "i'll look trans ",
#  'ana mkontsh h2ool l7ad bs 5las ba2a mo3zem 2lnas 3rft ': 'tab w embaby kan feeh 7aga w ata3too fag2a leeh ',
#  'how can you say thay do you like the syrup for it ': 'they are different sharbat not bad did u eaaaatt ',
#  '205 shofo meen el page su ': 'feen el pagw msh fahem ',
#  'wasww where are yoy you* why dont you take picss it is you so what it takes time the bacteria stays my whole throat is blocked i cannot swallow properly ': 'omg we\xe2\x80\x99re back to this again are u going to stay home for the next month ',
#  "w 3'albn knt a3rfha bs ana msh fkra ay haga tb3n ah tb3n ": 'hahahaha akeed ',
#  'pls cant even afford cup lids ': 'eyooo ma want my number ',
#  'so im gonna beg them to let me take it ': 'lmao i picked some random cs and stats courses ',
#  'is there a club or association ': 'yea data science club ',
#  'ok search it in forrest notes i just found it do u know numerical integration ': "i don't think it's in brian's notes i know how to derive the equations but i have no idea how to prove them use* ",
#  'enta batl3ab ma3 ahmed ': 'l2a ma3 nada bent keda bosy ta3aly fe el link dah ',
#  "i said friends i genera i meant everyone yesterday you brought her up yea to you you're always right ": 'so if i disagree with ur friends opinion i shouldnt talk ',
#  'https://youtube/gsvhaiwigue they sound like douchebags fuck em mit math btw if kanye went to mit at 3:32 ': 'who what is mit ',
#  'and a fucking life ': 'farah gave it to me ',
#  'come planninggg ': 'im just do arts ',
#  'i didnt call or text anyone else and i slept im not a liar ': "u even showed me her chat and said line doesn't work as if we're in the 19 century and then u said i'll call her infront of u and put it on speaker ",
#  "when do we get to stc i have class that ends at 8 again lmao i think that's enough time to copy though ": "lol i don't think i'll make it to stc very tired i'll just copy from home ",
#  'kinda i changed a bit from the old template ': 'do u know where i can get a good classic layout ',
#  'you went out ': 'yaaaa ',
#  'whaaaat are you homee ': 'n no the bus smells like shiy ',
#  'phobia hahahahhahahahahaha ': 'ah bnstahbel shwayya ',
#  'aly galo emial meen ghourir eno not accepted ': 'a7aaa galak ',
#  "oh i didn't need it i just used mvt in calc 1 and chain rule ": "that's for q1 right i was thinking about using the mvt too ",
#  'because whatt please i said im sorry and that it wont happen again and i know im wrong i feel really bad about it ': 'just because ',
#  'but you get it right ': 'yea ',
#  'i did tell you during the week ': "yea because i tried everything and u don't want to say ",
#  'code keda beta3ak w betestanna 7aga esmaha el mowaf2a el amneya ': 'a3raf ezay en el mowaf2a el amneya gatly ',
#  'ok bye ': 'im meeting lesbians today ',
#  'you wont accept i did shit in my exam ': 'u did the same mistake the last 4 terms ',
#  'what do you mean we know them ': 'who are they ',
#  'anyone have an outline of things we should study for 347 ': 'just form a basis that has dimv^2 + 1 dimension and contradict it to the fact that diml(v) is dimv^2 ',
#  'bzbt ': 'i found xo jacket in h&m kan gamed neeeeekkk 100$ not bad ',
#  'manwhore slutfaggot dicksack cuntbag ': "rabena ysam7ak lel walla l heater msh sha3'al ",
#  'so clicker 1 ': 'list empty (map the rest right ',
#  'good watch riverdaleeeee it has no sex scenes im so happy well there was one yesterday but kinda they just show that the couple will do it not when they do it ': 'u know this makes me not want to watch it right ',
#  'and you copied only the right ones yes ': 'u "read it" for me u didn\'t let me read it cause u told me wrong answers ',
#  'pass is were3 gat hatroo7 conestoga emta ': '6 7 i need to go to fido ',
#  'howa smae7 3ando mw3 ': '5adt mn 2 w 3 5alastohom w raga3tohomloo abl ma yebe3ha same7 ba3ha lwa7ed ye3rafoo ',
#  'yes85% engineering jobs shit ': 'where r u in ev1 ',
#  'she was talking to you bothhh ': "i didn't here anything ur mum said ",
#  'why only 30 ': 'there is no point of coming ',
#  'they didnt ask directly yea i know ': 'no they know what were u saying about u being in ur father shoes ',
#  'lol i mean i messaged him ': "i asked before i saw the guy's post lol do u wanna do me you hassan jack ",
#  'lol idk man i just said may ': '@cibi @hassaan send ur names to the guy i feel like we will lose him lol tax free saving account @cibi ',
#  'is the caps lock a trend in egypt stopping it why ': 'nooo ',
#  'no when you go take a selfie with her ': ' proof^ ',
#  'a5oia x@ ': 'enty 3andek a5 mesh enty wa7eeda ',
#  'i know what i did but the reason behind what i did wasnt to hide it from you ': 'u have no reason not to ',
#  "in sorry i took long i was packing we're leaving tommorow morning check out is at 10 ": 'what time tomorrow ',
#  'nas ktyr kat fksa derasa la tb3n omi est7ala trmy haga 3ala hesab haga tnia y3ni ': 'ana omy nafs el 7aga bardo ',
#  'egypt and saudi arent in the news about those security issues the rest are syrians are the only ones permanently banned ': 'tf egypt is always on there ',
#  'im infront of it okk ': "you're the blitz i threw my cap on the desk from the door and it got stuck like that ",
#  'okay so you will be staying school dormitory ': "yes insha'allah ",
#  "yeah alright that's good the cs assignment is so long too due after 145 midterm ": 'cs 135 right i did that in the weekend ',
#  'salemly 3aliha ': 'allaahh ysalemakk ',
#  'errryday ': 'wallaahhy i always look u in the eyes because i really like them not kiddingg this green ',
#  "i wouldn't recommend you take it alongside those math especially if you're not even in cs and if you dont like it no reason to its a huuuge time sink mahdood ": "yea i took cs 136 i wanna minor in cs but if i dont take it i wont be able too but if its too hard i'll just drop the minor if u just go to lectures u can code right away right i dont need to study something if its just long assignments i dont mind but i won't have time to study for it ",
#  "i've seen it in a documentary ": ' ',
#  'nothing changed ': 'anddd ',
#  "theres like a basket of chocolate in the hall of the bathroom and i've been sitting there for 10 min now and trying each flavor ": ' ',
#  'can i please call ': 'it looks so beautiful we should go one day or something like that ',
#  'add on the fact that u will live with girls and see them when u go out ': 'go continue working we will talk at night ',
#  'what do you mean what ': 'i focus on the pain i played this song like 20 times today ',
#  'and ur not even white exactly ': "i'm egyptian bitch we made spicy ",
#  'sanks you babe     ': 'send these to marion ',
#  'maybe u could try not to get diabetes gn ': 'gn ',
#  'oh true ': 'and cheeks ',
#  " hope your family's safe @mahmoud ashraf khairy ": '184 holy shit thank you\xe2\x9d\xa4\xef\xb8\x8f my family lives far from pretty far from sinai but i\xe2\x80\x99ll check on them the death toll is 235 now ',
#  'idk could you tell me bitch ': '3shan ta7teeh 5atein hahahhahaihahahhahahaa <<*are you fucking kiidding me* ',
#  ":( ma3lish isa you make it up in the final or in the rest of the course work that's completely fine mahmoud where are you staying im looking for a bachelor's apartment or a studio if you know anything around ": "i'm staying in dorm residence for now insha'allah i will do better in the final ",
#  'whats wrong with canada ': 'shiity country ',
#  'tb yalla ': "jk 2 hours i'll come at 12 ",
#  'clothes what car ': 'ur dads car ',
#  "we will kick pratyush if we don't find enough room don't worry ": 'lol ',
#  'hahahhahahahah la2 ana baroo7 belal fa bai2ba fadii ;) zakawa barduu ': 'heya noha dih lazeeza ',
#  'and models dont ': 'ofc no ',
#  'looooool i do stuff related to apis i had to help build a local database and fill it in with seed data by analyzing our code base to see which integration tests are failing and then inserting the appropriate data and some random api stuff not as interesting as ur shit and i can steal anyones credit numbers and run back to my coutnry either ': 'lmao im still confused af if i wanna do cs tho man y is this shit so hard to decide ',
like seeing stuff like that make it more specific say excel or something and u have space in the armenian community center u need to explain a bit more about microsoft applications in tim hortons u repeated good in both lines don't do that attention to detail of store management doesn't make sense don't add extra words just for the sake of it and ruin the meaning or grammar if u can't think of anything to add and u can't remove anything then leave it as it is in the transportation report second bullet point u didn't finish the sentence it ends with a the did u make the linkedin link and email a hyperlink can u go today and ask for my brother tell her there is an exam on monday and an exam on 2/10 which one does he take he would like to be more prepared so he wants the 2/10 ",
#  'hell * o:) ': 'lol ',
#  'omar bas e7na mmkn n2fl el mawdoo3 law enta mo3tard 3aleh ': 'la2 ana mafar2etsh m3aya ',
#  'bas you dont like all those finance courses ': 'i dont know what to do i love analysis and optimization tho ',
#  'emsek el tele ': 'la2 ommy hates7a nw ',
#  'noo i wouldnt i need you more than you need me ': 'i really wish ur love for me stays the same ',
#  'i was super happy ': 'samee ',
#  'el net bati2 molla el net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 molla vel net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 molla el net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 molla el net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 mollael net bati2 molla ': 'loooooooooooooz ',
#  'ma2oltesh la2 ': 'olt la2 ana hasta5demhom ',
#  'zaraaaa ': 'i found one that i really like ',
#  'post islam or what ': 'they do that with pastpapers ig ',
#  'w i went to one of boody ': 'then yara ',
#  "oh shittt we should hang out often my guys chill but doesn't want overnigjt guests lol cause 5 ppl share one washroom that's the only shitty part about the place lol and the room is kinda small if you're and hassaans guy is okay we can plan for sleepovers and stuff it'll be neat ": '5 ppl damn just make sure to wash the seat ',
#  "you ate pizza without me so we're even ": "u should study u didn't see me today to study not watch netflixxx ",
#  ' mood ': 'everyday imm going to sleepp ',
#  'had it from where ': 'his parents ',
#  "yess i know thats not at all thats so messed up i've heard a similar story that happened in saudi but she got killed at the end ": "saudi would've probably killed her ofc ",
#  'both part 1 and part 2 of serise ': "yea i finished q1 2 3 4 i think we will finish early today i'll get food from slc and head to stc i'll be there by 6 ",
#  'ezayak :d ': 'el7 ',
#  'ana za3lan awi msh 3ayez akalem 7ad w msh taye2 nafsi ': 'yaa3am 5alas el baka2 lel lah ',
#  'would that be an issue ': "no it's fine the difference isn't that big ",
#  'hasmig called you good morning\xe2\x9d\xa4\xef\xb8\x8f best of luck today you will do great\xe2\x9d\xa4\xef\xb8\x8f\xe2\x9d\xa4\xef\xb8\x8f think about it as such a big achievement that you will talk about for the rest of your lifeeee ': 'im going to be extremely late im still not even in the subway ',
#  'a7a yabni ur killing urself ': 'ma5alastohoosh aslan sayeb so2aleen sa3b 5awaa ',
#  'me either i mean the week ': "i'm talking about the whole week ",
#  'kan chat bas wala call kaman kan yenfa3 ta3mel meno free calls ': 'e7leff ',
#  'bmsko w 5alad slice ana knt fl tennis b3ml l slice l btnot w trg3 dy ': 'bgad 5alas eh da msh hala3bek enty la3ebty meen9 ',
#  'i just like it why ': 'bas they tag ur name and say u know what i mean ',
#  '0050 ': 'tf is wrong with 148 lmao in got rekt on assignment 4 ',
#  "what you will bro don't worry and yeah final that's my only hope ": 'nah the average last year was 40 lol 50 is pretty damn good ',
#  'wala yhemaak ana mestar5ema el it ': 'hat3melyy drop ',
#  'malish fih ': 'a7a ya ahmed ',
#  '3omraha ma 7atsada2 kelma mn bo2aha ': 'why walla u up im coming ur future ',
#  'my stomach hurts i havent cried this much since i opened quest ': 'i think i just died from laughing ',
#  'waitttt ': "they don't want me i'm leaving ",
#  'wat its irrational ': 'so u cant see it ',
#  "now you're insulting my family that we dont blend with other cultures no tell me how ": 'how is that bad i meant like even after being born in syria and living all their lives there they still talk and attached to armenia alot thats called being not blending into a culture its not bad alot of cultures are like that like jews for example arabs if they live in us they blend there and talk english they dont talk arabic properlu ',
#  'what wat dis ': 'auc someone posted this ',
#  'you realllyyyy cant keep comparing everyone i know with your relationship ': "i'm not bas at least u know her ",
#  'i told you they will travel and then come here ': "u definitely didn't say that where r they ",
#  '2 min left betekteb ensha walla eih yabni :p ': 'ana mabaktebsh 7aga :p ',
#  '7anshoof :p mmm ': 'mesh 3agbaky ',
#  'fl beet lol wala usd nezel l 156 masr om el donia ': 'you called ahmed a7a ',
#  'he willl ': 'idk hope so ',
#  'i have alooot of skirts so pick im not trying all ': 'skirt* show them to me ',
#  'ok im waiting ': "i don't like talking around people it's not about u being aware it's about u being too realistic u don't like to dream ",
#  'ok me 2 aslun kont ha2olak blel ': 'a7a ya m3alem kol da f so2al cs kosom cs 3ala dr racket msh so2al 7atta da question 2 part a 2 hours a7a ha3mel eh fl emta7an ana hatnak ',
#  "so you're playing with me ohhh wait yea you were ": 'ofcc did u take panadol ',
#  'noha called you noha called you ': 'the video chat ended ',
#  'ana katbt la amr um fed up btw wa mesh 7arod 3aleh law aklm ali leeh :( -- mesh 7arod ': 'rody oleelol leh ',
#  'lol did u finish all of hte first ones ': "yea i think it's easier than the second one ",
#  ' good night and have a good day tomorow\xe2\x9d\xa4\xef\xb8\x8f ': "i'll read this on the subway ",
#  ' random r workshop at work ': 'i thought that was ur ipad for a second lol what r u using r for ',
#  'ok what about koh ': 'i didnt see raphael at all lol last term like barely ',
#  'thats amazinggg inshallahh it isss ': "i didn't go to a single class ",
#  ' what do you mean overall ': 'cav ',
#  ' paaaaaaandaaaaaaaaaaaaaaaa omggg its their birthdayyyyt my birthday wasnt even this fancy howww is workk goingg where are youuu ': 'is that u i cant tell the ddifference between ur pic ',
#  'mahod efta7 el skype akalmk ': 'fein yabny ana mab2etsh al3ab crossfire ',
#  'hahahahahahah no wayyy ': 'in my prom i was like 15kg less ',
#  'the second reason i was upset ': "it's not overthinking it's a feeling ",
#  ' \xd8\xb9\xd9\x84\xd8\xb4\xd8\xa7\xd9\x86 documented ': '7ader ya tant hab3at now they refunded my 15$ the package will arrive on the 24th ',
#  'you cant talk your uncle is aroundd ': "i'm not studying either way no i'm outside ",
#  'with who ': 'noah ',
#  '<3 fag ': 'hateegy or nah heya muslima ',
#  ':p meen el o5t el fadla wa betsa3dha fi eh isa ': 'noooooora ',
#  'anytime man and yeah templates are always necessary ': 'i change "word" to "yrd" i can\'t add the w lol ',
#  '5:30 or 5ish ': '5:30 ok if before that call me u used to call me on my cellphone ',
#  'start what being productive no * didd youuu ': "ofc no i'm having breakfast ",
#  'can u come fast a guy just asked me out ': "what what do you mean u can't say something like that then disappear ",
#  'what are you doing are you on the phone im down i see youu just for half an hour then you can leave ': "why i'm studying with hassan ",
#  'yes we will because it can be fixed ': 'no do whatever u want ',
#  'the thing u sent en mary had sex before marriage and created a relegion to cover this wedlock marriage most probably ': 'the guy can fucking talk when he was a baby ',
#  'rabe3 ebn el mra ahahaha rabe3 hahaha ': 'aywwwaa rabee3 xd ',
#  'are you sure ': "i wasn't with u at that time u were like 15 or smth ",
#  'then he took the phone and omar wanted timbets and i said the whole showcase is finished except crossiants ': ' ',
#  'cuz t = {x + w: x belongs to v} does that mean any arbirtrary x or one specific x ': 'on the group they just asked laindon said arbitrary ',
#  'whyyyy when i loveee the characterrr i really didnttt why would i have a problem with you putting that ': "don't u remember ",
#  'long distance wont work ': 'wow why wait when we can do it now ',
#  'tab bos 3ayzen nfkr fe wa7dah tanya 2w ns2l mourad bokra isa ': 'mashy ',
#  'but do you just go on google ': "yes it didn't happen once just random questions i get i google them that's i ",
#  'because of how ugly i look in that picture ': 'yea ',
#  'aywa ': 'da bynekoohom abl ma yakloohom ',
#  'muslims as in ikhwan isnt that still happening now ': "no all muslims and all christians it's different ",
#  'kanet fi els wea meshyet ': 'leeeeeeeeeeeeeeeeeeeh ',
#  'whaaatttr howwwww did it stop nowww put ice on it pleaseee ': 'idk ',
#  'noo it looks so cool when we passed by its so old and looked european ': "u should've went to ny in the end ",
#  'any luggages ': '1 ',
#  'i just finished now ': 'come mc ',
#  ...}

# %%
print 'Total len of dictionary', len(FacebookDictionary)
# Out:
# Total len of dictionary 56603

# %%
import numpy as np
print 'Saving conversation data dictionary'
np.save('conversationDictionary.npy', FacebookDictionary)
# Out:
# Saving conversation data dictionary

# %%
conversationFile = open('conversationData.txt', 'w')
for key,value in FacebookDictionary.iteritems():
	if (not key.strip() or not value.strip()):
		# If there are empty strings
		continue
   	conversationFile.write(key.strip() + value.strip())

# %%
import tensorflow as tf 
import numpy as np 
import re
from collections import Counter
import sys
import math
from random import randint
import pickle
import os

# %%
def processDataset(filename):
	openedFile = open(filename, 'r')
	allLines = openedFile.readlines()
	myStr = ""
	for line in allLines:
	    myStr += line
	finalDict = Counter(myStr.split())
	return myStr, finalDict

# %%
def MyprocessDataset(filename):
    readFile = open(filename, 'r') # 'r' means read file
    myLines = readFile.readlines()
    myStr = ""
    for Line in myLines:
        myStr += Line
    finalDict = Counter(myStr.split())
    return myStr, finalDict

# %%
fullCorpus, datasetDictionary = processDataset('conversationData.txt')
print 'Finished parsing and cleaning dataset'

wordList = datasetDictionary.keys()

with open("wordList.txt", "wb") as fp: 
    pickle.dump(wordList, fp)
# Out:
# Finished parsing and cleaning dataset

# %%
import tensorflow as tf 
import numpy as np 
import sys
from random import randint
import datetime
from sklearn.utils import shuffle
import pickle
import os

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# %%
# Hyperparamters
batchSize = 24
maxEncoderLength = 15
maxDecoderLength = maxEncoderLength
lstmUnits = 112
embeddingDim = lstmUnits
numLayersLSTM = 3
numIterations = 500000

# %%
with open("wordList.txt", "rb") as fp:
	wordList = pickle.load(fp)

# %%
wordList
# Out:
# ['studyyyyyynothing7t',
#  'beautifulbelieve',
#  'http://wwwfacebookcom/photophpfbid=179094782194340&set=a15600308450351026253155844844519334&type=1&theater',
#  'episodebaratheons',
#  'peoplei\xe2\x80\x99m',
#  "3'am2",
#  'friendzonedi',
#  'gag',
#  'wannaaaa',
#  'spiders',
#  'hanging',
#  'minthere',
#  'dorha',
#  "schooli'm",
#  'tomisa',
#  'enhrdaama',
#  'jokescheck',
#  'lesterdooooo',
#  'lolstillmine',
#  '--ya3am',
#  'gab',
#  'hairlier',
#  ':de3meleelo',
#  'opener',
#  'storiesim',
#  'crossbas',
#  'moreee',
#  "men3'er",
#  'lateahhh',
#  'whatfinished',
#  'diy(0)=0',
#  'hahahah',
#  'europewhere',
#  'discribed',
#  'mindblownlol',
#  'nightttttyywhy',
#  '\xd8\xb3\xd8\xb1\xd9\x8a\xd8\xb9\xd8\xa9',
#  'right"im',
#  'sendingu',
#  'thenpmathwhether',
#  'sendingi',
#  'studentsplease',
#  'bringing',
#  'sendingg',
#  'lollolwow',
#  'hasmigwhatnothing',
#  "whatttit's",
#  'mazoneshomaleven',
#  'datinglelyes',
#  'meeeedo',
#  'wooden',
#  '598s',
#  'infinityyeamy',
#  'wednesday',
#  'msbtaha',
#  'sa777ok',
#  'themvlow',
#  'elgaw',
#  'ballashhh',
#  'fhmtk',
#  'mcdonaldss',
#  'gom3a7amdellaa',
#  '27$',
#  '27%',
#  'mo3trf',
#  'worsenoo',
#  'bta3hahahahahhahahahahahahhahahahahhahhahahahahahahahahhahahahahahahahahhaaaa',
#  '0050',
#  '271',
#  'happenok',
#  'masterraceyou',
#  '275',
#  '277',
#  'questfuck',
#  'finalsss',
#  'backthats',
#  'errorr',
#  'errors',
#  'starboy',
#  '98write',
#  'hateeha',
#  'sa7i7',
#  'yanhar',
#  'bnel3ab',
#  'laterlol',
#  'designing',
#  'o:)meeni',
#  '\xd8\xb6\xd8\xa7\xd8\xb9',
#  'changeis',
#  'nahmasr',
#  'songsself',
#  'shitmohamed',
#  'hedomi',
#  'uppppppou',
#  'famla2never',
#  '3awzany',
#  '27i',
#  'templatehow',
#  'brainwashed',
#  'csana',
#  '3awzana',
#  'lolshut',
#  'soulif',
#  'motherrmy',
#  'usmatkalemha',
#  'firsther',
#  'kids',
#  'it\xe2\x9d\xa4\xef\xb8\x8f',
#  'gobus',
#  'roomokokokokokoku',
#  'la7zt',
#  'exactlywhaaat',
#  'meshyo*',
#  'allllw',
#  'converges5alas',
#  'controversy',
#  'sa7ii',
#  'kida',
#  'la7za',
#  '<33mtn',
#  'kidd',
#  'sa7ia',
#  'kidi',
#  'sa7ib',
#  'talba',
#  'kidn',
#  'doableyou',
#  'aslankkkkkkyou',
#  'stilllaletly',
#  'projection',
#  'hw',
#  'feesalright',
#  'usafuck',
#  'mclaurin',
#  'neekkkkyea',
#  'bo2wow',
#  'e5',
#  'e4',
#  'weekendgoodluck',
#  'engl',
#  'knowohh',
#  'beginningwere*yes',
#  'elseeowwwoh',
#  'matgeebyy',
#  'agassi',
#  'dna',
#  'uuuuuyou',
#  '\xd9\x85\xd9\x82\xd9\x81\xd9\x88\xd9\x84',
#  'insecurity',
#  'dno',
#  "detergenti'm",
#  'workstopppppp',
#  'dnt',
#  "upyou're",
#  'yoyappointments',
#  'bayyyy',
#  'georgeyea',
#  'differencessjust',
#  'populationw',
#  '5laseat',
#  'goodwe',
#  '250kol',
#  'thismana',
#  'isait',
#  'yahoo',
#  'pleaaaseeenoooooo',
#  'tooyour',
#  '3rfahaaa',
#  'onethank',
#  'firstlike',
#  'someonemanager',
#  'intake',
#  'sleeppart',
#  'ashoofak',
#  '5etm',
#  "onni'm",
#  'ip',
#  'vegas',
#  'a7aawhatw',
#  'generalim',
#  'slepyyalla',
#  'gam3aasli',
#  'begadtab',
#  '20good',
#  'accenthe',
#  "india's",
#  'jknxd',
#  'wana',
#  "hobbihe's",
#  'wank',
#  'wann',
#  'payyyyes',
#  'etharena',
#  'titanium',
#  'coopif',
#  'scoresohh',
#  "thenu're",
#  'menek',
#  '4&5',
#  'wentaaedahhh',
#  'wany',
#  'themok',
#  'nsafr',
#  'expensiveall',
#  'narcosu',
#  'eihvirgo',
#  'narcoss',
#  'longokkksend',
#  'travel',
#  'waterlooeverytaaaang',
#  'smthyou',
#  'houseahhahameen',
#  'coursesohh',
#  'a3eenya7a',
#  'youua7a',
#  'mdareb',
#  'beyea',
#  'meeneb3eed',
#  'ko7lyymsa',
#  'honored',
#  'waitinggg',
#  'sectionnfrom',
#  'tabe3y',
#  'isik',
#  'akhooya',
#  'sedy',
#  '5korean',
#  'heytaha',
#  'wrong',
#  'hahahaaywwwaa',
#  'alootone',
#  'stollen',
#  'masterlast',
#  'oksem',
#  'by3melehaa',
#  'computersnigga',
#  'torontoyei',
#  '7aigabhomisa',
#  'finalif',
#  't2dm',
#  'waysame',
#  'chapterss',
#  'finalim',
#  'thoksdvj',
#  'wentawater',
#  'bt5aby',
#  'onyeah',
#  'mamathanks',
#  '8)just',
#  ":'(nile",
#  'a3it',
#  't2dr',
#  'deadlinehat-',
#  'dontgo',
#  'timehat3ady',
#  '854%',
#  'welcomee',
#  'worriesor',
#  'didnynothing',
#  'responseafter',
#  '(us)',
#  'realisticwhat',
#  'weekbyei',
#  'poochedthe',
#  'wowtrue',
#  'salaaamwallahy',
#  'a1]ohhh',
#  'fir',
#  'uor',
#  'restaurantsr',
#  'uop',
#  'hiheyana',
#  'fit',
#  'uot',
#  'screaming',
#  'fix',
#  'oneeveryone',
#  'tsale7ha',
#  'dramaridgeview',
#  'sa\xd8\xa7\xd9\x84\xd8\xad\xd9\x85\xd8\xaf',
#  'e3meleelonot',
#  'fid',
#  '*ya',
#  'uok',
#  'fik',
#  'fih',
#  'uoh',
#  'fin',
#  'uon',
#  'fil',
#  'searchwhat',
#  'zucker',
#  'kedastar',
#  'studyywoww',
#  'isidk',
#  'vouchers',
#  'rage3true',
#  'onewere',
#  'smhto',
#  ':shhahahahaha',
#  'wal3ana',
#  'areyouuu',
#  'helpur',
#  'lol10',
#  'ndemtmshh',
#  '\xd9\x85\xd8\xa7\xd9\x84infection',
#  'womanwhattt',
#  'talabtaha',
#  'waterloopls',
#  'examsdearso',
#  'dadheya',
#  'tele3hmmmm',
#  'a3rafha',
#  'yaokim',
#  'youuuthey',
#  'timeout',
#  'midtermedanl2aaaaaaa',
#  '3dont',
#  'mekamela',
#  'isya',
#  'setyeaa',
#  '\xd8\xaa\xd8\xae\xd9\x84\xd9\x89',
#  'egypttt',
#  'theoremsw',
#  'whonoah<3',
#  'hal3aab',
#  'crywhyokayy',
#  'egyptto',
#  'homeokkkwhats',
#  'fallakeed',
#  '2day',
#  "promiseyeesa3'eer",
#  'seriouslylike',
#  'feehabro',
#  'r5esale3ha',
#  'darbatry',
#  '***ohbhzar',
#  'sleeooyou',
#  'hnakwallahy',
#  'daysbecause',
#  'snoringml7zagebt',
#  'meeewhen',
#  'dodieiieiieieiieeiiee\xd9\x81\xd9\x8a',
#  'skypeya3ny',
#  'nemti',
#  'adapt',
#  'classokk',
#  'size',
#  'dizzyfor',
#  '7im',
#  'gb4h',
#  'tsd3ohahahahha',
#  'freezingwhat',
#  'differenceanswer',
#  '\xd8\xa7\xd9\x8a\xd8\xa7\xd9\x85',
#  '3ebfe',
#  'ovenits',
#  'atla3ma',
#  '20685005',
#  "you**i'm",
#  'sheet',
#  'nos3alaa',
#  'baha2eya',
#  'dayshttps://youtube/ts0hvypeuk0',
#  'selfo',
#  'm5lya',
#  'jetlagand',
#  'selff',
#  '\xd8\xa7\xd9\x84\xd8\xa3\xd9\x88\xd9\x84\xd8\x8c',
#  'studyingshould',
#  'bookmark',
#  'dontwhyyy',
#  'disturbed',
#  'lateeeeee',
#  'figuredand',
#  'dawah',
#  'scienceohh',
#  '3atabasha3roo',
#  'itnooo',
#  'unchartedwat',
#  'loook',
#  '5afeef',
#  'aloneno',
#  'thursdayerryday',
#  'loool',
#  'nowwow',
#  'u\xe2\x80\x99ve',
#  'muchh\xe2\x9d\xa4\xef\xb8\x8f\xe2\x9d\xa4\xef\xb8\x8f\xe2\x9d\xa4\xe2\x9d\xa4',
#  'mutalwow',
#  'sama3atak',
#  'passwordi',
#  'nowwoh',
#  '(except',
#  'nowwok',
#  "na3'ma",
#  'bilzerian',
#  'olds',
#  'btl3bha',
#  'themlater',
#  'seetheres',
#  'chancema7moud',
#  'talkinh*',
#  'hadod',
#  'bitwhenokay',
#  'needed',
#  'master',
#  'oldd',
#  'herselfhymshyyy',
#  'lelstart',
#  'oldi',
#  'proofif',
#  'bleedsno',
#  'genesis',
#  "peoplewe'll",
#  '11thu',
#  'm2oltleesh',
#  'ehdahaga',
#  'rnyaallaa',
#  'pleasejust',
#  'jobmine',
#  'whennyessonly',
#  'borroe',
#  'watcjing',
#  'bffohhh',
#  'youinstead',
#  'ya5raboha',
#  'mennaoh',
#  "youssefhe's",
#  'ahmed',
#  'ahamd',
#  'obviousallah',
#  'sheel',
#  '3absaia3alafekra',
#  'manemteshhhdid',
#  'meomfg',
#  'augustsame',
#  'htft7lk',
#  'planningwhat',
#  'bdaaaanharoo7',
#  "g3ana'mfish",
#  'shampoos',
#  'feeling',
#  'prankk',
#  'by2atelo',
#  'brothereven',
#  'accand',
#  'yeezys',
#  'weeklolokayy',
#  '7ayatynot',
#  'yesterdaylol',
#  '2020sametalk',
#  'onecurve',
#  'popularim',
#  "hahahai'll",
#  'chatshe',
#  'carthere',
#  '\xd9\x88\xd8\xa5\xd9\x84\xd8\xa7',
#  'overrrrfrom',
#  'me3aya',
#  'nadaraahow',
#  'awehahahhahaa',
#  'this\xd8\xa5\xd9\x8a\xd9\x87',
#  'wholesome',
#  'coursesnonoo',
#  '7odaaaa',
#  'vinylsbecause',
#  'problemwere3',
#  'nothingggmisrrak',
#  'ashteri',
#  'getwtf',
#  'joking7asak',
#  'tararaa',
#  'rhcp',
#  'whyaysee',
#  "isayou're",
#  'uuuucuz',
#  'thoalright',
#  'feinbey7egoo',
#  'shittoday',
#  'seeokmy',
#  'fassal',
#  'simplify',
#  'soemone',
#  'liedwell',
#  'icloud',
#  '1973mesh',
#  'ashoofpregnant',
#  '5aalaas',
#  'zou2ak',
#  '100vectors',
#  'aaaaaamgooo',
#  'majo',
#  'bikini148',
#  'gma3a',
#  ':dwnttty',
#  'hoursyeah',
#  'guyywoah',
#  'thaat',
#  'tech',
#  'isaeshta',
#  'ynfa3',
#  'byshtmo',
#  'doesn\xe2\x80\x99t',
#  'nes2alo',
#  '7asb',
#  'witheveryone',
#  'sayinf',
#  'saying',
#  'rightyeathe',
#  'whomisnt',
#  'ma2darsh',
#  'longlolyeah',
#  ':d5555',
#  'realgfybut',
#  '"ranked',
#  'aduiaeh',
#  'le7adda',
#  'dishesss',
#  '(y)600ms',
#  'ittttsome',
#  'dickeh',
#  'africahwa',
#  '3aarf',
#  'tempted',
#  'expensiveexam',
#  'nazlha',
#  'a5barek100%',
#  'nadaalll',
#  'tearsbruh',
#  'bullshitted',
#  'clicked',
#  'hawaiiiithese',
#  'wewdo',
#  'descriptionin',
#  'toobut',
#  'doezay',
#  'clicker',
#  'magani',
#  'itjordan',
#  'hoeing',
#  '\xd8\xaa\xd8\xa8\xd8\xb5\xd9\x84\xd9\x8a',
#  'plate',
#  'afalt',
#  'menooou',
#  'ardbas',
#  'plath',
#  'ikhwansana',
#  'btgeeb',
#  'bedmaybe',
#  '2atetdjak',
#  'afalo',
#  'frommmmozee3',
#  "mani'm",
#  'themnooo',
#  "cu're",
#  'bahazarwhen',
#  'willheyess',
#  'nicely',
#  'tomorrowhe',
#  'mwguud',
#  'whorestf',
#  'patch',
#  'sha5eet',
#  'walaaywwa',
#  'tomorrowhy',
#  'akhlas',
#  'byeshra7oo',
#  "downtowni'm",
#  'mabsoott',
#  'youuumiss',
#  'gosetyy',
#  'yesstop',
#  'dangerouslong',
#  "baddu're",
#  'worryyyyea',
#  "don'tyou",
#  'mattertrue',
#  'matbo3',
#  'yeaaasoon',
#  '3rfaww',
#  't2eel',
#  'seriouslyi',
#  'saythe',
#  'tommorowwthis',
#  'kedawell',
#  'agobruh',
#  'studiokitchenerno',
#  '7agarn',
#  'ezayif',
#  'meesmha',
#  'minnlies',
#  'tari2a',
#  'lots',
#  'somethingnolaa',
#  'lott',
#  'loti',
#  'studyingmmm',
#  'irl',
#  'dorak',
#  'talaterba3',
#  'describedu',
#  '3aila',
#  'notdepression',
#  'fkrashaklaaha',
#  'darooryi',
#  'writeover',
#  "whythat's",
#  'extend',
#  'nature',
#  'commeeee7aga',
#  'doesntplease',
#  'diessssstoo',
#  "351they're",
#  'extent',
#  'dididk',
#  'gonnaa',
#  'seriously"',
#  'a3melrip',
#  'computationshttp://wwwcibegcom/english/pages/cibcurrenciesaspxhttps://wwwgoogleca/searchclient=safari&rls=en&q=usd+to+egp&ie=utf-8&oe=utf-8&gfe_rd=cr&ei=sbegwpr0gqyc8qemiyxwcqnot',
#  'godhttps://enwikipediaorg/wiki/tomb_of_lazarus',
#  'sayhahaha',
#  'tesale7',
#  'fromhe',
#  'yeasloth',
#  "nicei'm",
#  'fifth',
#  'facekkkhsibk',
#  'timenever',
#  'umakuntsh',
#  "hoes****u'reee",
#  'b7bha',
#  'lookin',
#  '9cute',
#  'lunches',
#  'metoqaayalla',
#  'betterrrr\xd9\x85\xd9\x81\xd9\x8a\xd8\xb4',
#  'assup',
#  'assur',
#  'trueyea',
#  'japanese(y)',
#  'okkkk',
#  'onehahahahha',
#  'trueyes',
#  'laughana',
#  'awqy',
#  'smackdown',
#  'etlub',
#  'loudwhat',
#  'tab3an',
#  'meanidk',
#  'fri',
#  'fro',
#  'bothers',
#  'mucj',
#  'clubnoalso',
#  'much',
#  'frw',
#  'timeholy',
#  'fry',
#  'correction',
#  'fenakfl',
#  'ga3annot',
#  'tonightmsh',
#  'ra2bt',
#  'spit',
#  'xdpretty',
#  'doubti',
#  'newu',
#  "fbi'll",
#  'doubts',
#  "goi'll",
#  'spin',
#  'fagerhow',
#  'baishrab',
#  '13th',
#  '\xd9\x8a\xd8\xb3\xd9\x84\xd9\x85\xd9\x83*do',
#  '4please',
#  'hanedres',
#  'roland',
#  'atamnk',
#  'bokra\xe2\x9d\xa4\xef\xb8\x8fyou',
#  'todaywork',
#  'btswar',
#  'qssamei',
#  'fr2',
#  'yallaaalol',
#  'e^-2c',
#  'yesterdaykhalas7a3ayatlak',
#  'youmatnazl',
#  'koha',
#  'unot',
#  'lolwhattt',
#  'youssef_yassin',
#  'emtakhalas',
#  'girlwow',
#  'kohi',
#  'ateselawee',
#  'itthen*el',
#  'sa7it',
#  'oltelhayou',
#  'wlaahymlksh',
#  'madrasa3and',
#  'xdxdthank',
#  'coldthen',
#  'christiansnowwlc',
#  'oktoo',
#  'youkhalas',
#  'unoo',
#  'hone',
#  'go*obbbba',
#  'hong',
#  'hona',
#  'inwtf',
#  'tmren\xe2\x80\x9ci',
#  'sufferingyour',
#  'homiehttps://wwwfacebookcom/hashtag/%d8%b1%d8%b4%d8%a7_%d9%88_%d8%ad%d9%85%d8%a7%d8%aa%d9%87%d8%a7source=feed_text&story_id=1439402869455794#',
#  'forfirst',
#  'pleaseenola2',
#  "uppppu're",
#  'sa7im',
#  'ded<3mat2ol',
#  'outits',
#  'genocidewhat',
#  'mahalat',
#  'stop7aga',
#  'eldohr',
#  'workingbecause',
#  'issac',
#  ':pb2olak',
#  'alreadyofci',
#  'y*masalan',
#  'excuseslunchmy',
#  'issai',
#  'daywaaaaaaaaaaaawwwww',
#  'tomorrowyea',
#  'moregets',
#  '2bnyxddkman',
#  'knowwwreddit',
#  ':(nour',
#  'bt2lesh',
#  'morning34',
#  'tomorrowyes',
#  'wa2efi',
#  '8)myyy',
#  'judgement',
#  'itnope',
#  'https://idopese/torrent/game%20of%20thrones%20s07e06/034116c6c870170eea355a0d20381069d1ecb9be/fref=gc',
#  'mentors',
#  'henakw',
#  'everon',
#  'menwar',
#  'academic',
#  'henakk',
#  'academia',
#  'henakl',
#  'courseswhy',
#  'there\xe2\x80\x99s',
#  'eha7a',
#  'corporate',
#  'ma3lenameen',
#  'exactlywhy',
#  'uyeah',
#  'http://wwwessmx/%d9%84%d9%88%d9%84%d8%b2/52004looool',
#  'lasst',
#  'herewoowowowoweshta',
#  'appropriately',
#  'uyeaa',
#  'fridgenick',
#  "mathematiciansi'm",
#  'hatly',
#  'employersyes',
#  "zah2aani'll",
#  'lassi',
#  'howtorontomasters',
#  'reasonyou',
#  '7agahaha',
#  'hai',
#  '7ait5ol',
#  'hak',
#  'fidoaight',
#  'ham',
#  'citycan',
#  'hao',
#  'chemana',
#  'haa',
#  'had',
#  'tarabeza',
#  'times:$',
#  'weeeki',
#  'whennnntf',
#  'weeekk',
#  '\xd9\x88\xd9\x8e\xd8\xa7\xd9\x84\xd8\xa3\xd9\x8e\xd8\xa8\xd9\x92\xd8\xb1\xd9\x8e\xd8\xb5\xd9\x8e',
#  'whathrm',
#  'classidk',
#  't3shroon',
#  'har',
#  'has',
#  'hat',
#  'hav',
#  'haw',
#  'ehokkk',
#  ':(3amal',
#  'itelhamdullaah',
#  'a2olooo',
#  'elders',
#  'moroccan',
#  'meda5lt',
#  'pranks',
#  'm2lab',
#  '7ankr',
#  'pissedhow',
#  'lifetouchedno',
#  'weekendbut',
#  'sleepingwtf',
#  '12:30',
#  'sufferingfuck',
#  'heactually',
#  'photosim',
#  'ha*',
#  'anzelokay',
#  'giftti',
#  '30same',
#  'ehaa7a',
#  'itokk',
#  'fyabny',
#  "communicationyeswe're",
#  'times:d',
#  'agodrive',
#  'sweatpants/leggings',
#  'thosalam',
#  'omgits',
#  'yostora7eeeeeh',
#  'coldddd',
#  'ha2',
#  'ha3',
#  'anythingyess',
#  'kabnory98tab',
#  'mabetrodesh',
#  'ba2fel',
#  'wantedchanging',
#  'wend',
#  'crowd',
#  'jknjkn',
#  'themlevel',
#  'mosques',
#  'thissits',
#  'crown',
#  'whoseriouslywhat',
#  'crows',
#  'l2eitek',
#  "muchthat's",
#  'thohope',
#  'wgbat',
#  'sheetein',
#  '\xd8\xa8\xd8\xa7\xd8\xa8\xd8\xa7\xd8\xb9\xd8\xa7\xd9\x85\xd9\x84',
#  'secondahh',
#  'anythingdrink',
#  'mat2olish',
#  'bottom',
#  'lockdown',
#  'projectno',
#  '</3better',
#  "co-oppinsha'allahimpossible154",
#  'yastaamathif',
#  'hahahayea',
#  'completly',
#  'masnnnhow',
#  'thatidk',
#  'classaa7a',
#  'hs7ahahahhahah',
#  'impossibleit',
#  'anyyou',
#  'gotrain',
#  "ityou've",
#  'emtaa7ee',
#  'impossiblein',
#  'upmsh',
#  'comesnooooooooo',
#  'saygo',
#  'takewhatwhyyy',
#  "chaptersi'm",
#  'impossibleif',
#  'mosque"',
#  'saraaa',
#  'cinemaits',
#  '7fl',
#  'u*\xd8\xa8\xd9\x8a\xd9\x82\xd9\x88\xd9\x84\xd9\x83',
#  'busssit',
#  'aloooooooooooooooo',
#  'bardoaywan',
#  'nvmthats',
#  'ya5dek',
#  'etahametny',
#  'lyricsofcyeah',
#  'marksdamn',
#  'ml3bthashmshh',
#  'whwr',
#  'bullshittingwhat',
#  'ehwere3',
#  'honeymoon',
#  'ba2aor',
#  'homrnot',
#  'o3ody',
#  '\xd8\xa7\xd8\xb9\xd9\x85\xd9\x84',
#  'ba2aok',
#  'youmeshtta',
#  'hist235',
#  'alivewho',
#  'shoots',
#  'kadbaha',
#  'ceoim',
#  'sa2aletyea',
#  'placesaslan',
#  'townboston',
#  'panthis',
#  'shittycause',
#  'respectfulwala',
#  'raped',
#  'doesntliar',
#  'pedophileteens*',
#  "y3'ayar",
#  ':dyomnaaa',
#  'bracess',
#  'plscrushed',
#  'alexandrian',
#  'todaytill',
#  '30s',
#  '3omrek',
#  "pointyou're",
#  '0*x',
#  'overmydickatiieatttt',
#  'twin*so',
#  'sleepnoooo',
#  '^slow',
#  'bnetkalem',
#  'universityy',
#  'u1:20',
#  ':sbey2ooly',
#  'normalel',
#  'herhahah',
#  'longidk',
#  'peoplelike',
#  'awythats',
#  'isatewsall',
#  'congratulations',
#  '7aagaa',
#  'greatt:)))if',
#  "else's",
#  'hahahahahahhahahahahahahaha',
#  'fagwha',
#  '1600i',
#  'niceso',
#  'hungeyok',
#  "millionwe're",
#  'gc*lol',
#  'mawdoo3rofl',
#  'niiiceu',
#  'eatbkyea',
#  'conclusionsis',
#  'kedathb',
#  'kedathe',
#  'haderentyy',
#  'disgrace',
#  '[[asa7bi]]',
#  'barrymore',
#  "det(a')",
#  'mirror',
#  'yabnyohh',
#  'fagloli',
#  "equalitythat's",
#  'to2af',
#  'boardhasmiigg',
#  'tiredohh',
#  'diagonali',
#  'mss7eyen',
#  'rnimm',
#  'momentsshoofyy',
#  'doinghatinggyet',
#  '"brother"why',
#  ":')inshaa'allaah",
#  'aretrue',
#  'cambodia',
#  'list27',
#  'emantant',
#  'alleveryone',
#  'it*you',
#  'bossim',
#  ':penbasaty',
#  'replied:p',
#  'http://wwwyoutubecom/watchv=alybshogofy',
#  'wontfuckkk',
#  'youmana',
#  'm3ady',
#  'xdaaahyou',
#  ';)eeh',
#  'diethats',
#  'notcan',
#  'yeswhere',
#  'karimno',
#  ":'(so",
#  ...]

# %%
vocabSize = len(wordList)

# %%
wordVecDimensions = 100

# %%
padVector = np.zeros((1, wordVecDimensions), dtype='int32')
EOSVector = np.ones((1, wordVecDimensions), dtype='int32')

# %%
wordList.append('<pad>')
wordList.append('<EOS>')
vocabSize = vocabSize + 2

# %%
def createTrainingMatrices(conversationFileName, wList, maxLen):
	conversationDictionary = np.load(conversationFileName).item()
	numExamples = len(conversationDictionary)
	xTrain = np.zeros((numExamples, maxLen), dtype='int32')
	yTrain = np.zeros((numExamples, maxLen), dtype='int32')
	for index,(key,value) in enumerate(conversationDictionary.iteritems()):
		# Will store integerized representation of strings here (initialized as padding)
		encoderMessage = np.full((maxLen), wList.index('<pad>'), dtype='int32')
		decoderMessage = np.full((maxLen), wList.index('<pad>'), dtype='int32')
		# Getting all the individual words in the strings
		keySplit = key.split()
		valueSplit = value.split()
		keyCount = len(keySplit)
		valueCount = len(valueSplit)
		# Throw out sequences that are too long
		if (keyCount > (maxLen - 1) or valueCount > (maxLen - 1)):
			continue
		# Integerize the encoder string
		for keyIndex, word in enumerate(keySplit):
			try:
				encoderMessage[keyIndex] = wList.index(word)
			except ValueError:
				# TODO: This isnt really the right way to handle this scenario
				encoderMessage[keyIndex] = 0
		encoderMessage[keyIndex + 1] = wList.index('<EOS>')
		# Integerize the decoder string
		for valueIndex, word in enumerate(valueSplit):
			try:
				decoderMessage[valueIndex] = wList.index(word)
			except ValueError:
				decoderMessage[valueIndex] = 0
		decoderMessage[valueIndex + 1] = wList.index('<EOS>')
		xTrain[index] = encoderMessage
		yTrain[index] = decoderMessage
	# Remove rows with all zeros
	yTrain = yTrain[~np.all(yTrain == 0, axis=1)]
	xTrain = xTrain[~np.all(xTrain == 0, axis=1)]
	numExamples = xTrain.shape[0]
	return numExamples, xTrain, yTrain

# %%
numTrainingExamples, xTrain, yTrain = createTrainingMatrices('conversationDictionary.npy', wordList, maxEncoderLength)
np.save('Seq2SeqXTrain.npy', xTrain)
np.save('Seq2SeqYTrain.npy', yTrain)
print 'Finished creating training matrices'
# Out:
# Finished creating training matrices

# %%
def getTrainingBatch(localXTrain, localYTrain, localBatchSize, maxLen):
	num = randint(0,numTrainingExamples - localBatchSize - 1)
	arr = localXTrain[num:num + localBatchSize]
	labels = localYTrain[num:num + localBatchSize]
	# Reversing the order of encoder string apparently helps as per 2014 paper
	reversedList = list(arr)
	for index,example in enumerate(reversedList):
		reversedList[index] = list(reversed(example))

	# Lagged labels are for the training input into the decoder
	laggedLabels = []
	EOStokenIndex = wordList.index('<EOS>')
	padTokenIndex = wordList.index('<pad>')
	for example in labels:
		eosFound = np.argwhere(example==EOStokenIndex)[0]
		shiftedExample = np.roll(example,1)
		shiftedExample[0] = EOStokenIndex
		# The EOS token was already at the end, so no need for pad
		if (eosFound != (maxLen - 1)):
			shiftedExample[eosFound+1] = padTokenIndex
		laggedLabels.append(shiftedExample)

	# Need to transpose these 
	reversedList = np.asarray(reversedList).T.tolist()
	labels = labels.T.tolist()
	laggedLabels = np.asarray(laggedLabels).T.tolist()
	return reversedList, labels, laggedLabels

def translateToSentences(inputs, wList, encoder=False):
	EOStokenIndex = wList.index('<EOS>')
	padTokenIndex = wList.index('<pad>')
	numStrings = len(inputs[0])
	numLengthOfStrings = len(inputs)
	listOfStrings = [''] * numStrings
	for mySet in inputs:
		for index,num in enumerate(mySet):
			if (num != EOStokenIndex and num != padTokenIndex):
				if (encoder):
					# Encodings are in reverse!
					listOfStrings[index] = wList[num] + " " + listOfStrings[index]
				else:
					listOfStrings[index] = listOfStrings[index] + " " + wList[num]
	listOfStrings = [string.strip() for string in listOfStrings]
	return listOfStrings

def getTestInput(inputMessage, wList, maxLen):
	encoderMessage = np.full((maxLen), wList.index('<pad>'), dtype='int32')
	inputSplit = inputMessage.lower().split()
	for index,word in enumerate(inputSplit):
		try:
			encoderMessage[index] = wList.index(word)
		except ValueError:
			continue
	encoderMessage[index + 1] = wList.index('<EOS>')
	encoderMessage = encoderMessage[::-1]
	encoderMessageList=[]
	for num in encoderMessage:
		encoderMessageList.append([num])
	return encoderMessageList

def idsToSentence(ids, wList):
    EOStokenIndex = wList.index('<EOS>')
    padTokenIndex = wList.index('<pad>')
    myStr = ""
    listOfResponses=[]
    for num in ids:
        if (num[0] == EOStokenIndex or num[0] == padTokenIndex):
            listOfResponses.append(myStr)
            myStr = ""
        else:
            myStr = myStr + wList[num[0]] + " "
    if myStr:
        listOfResponses.append(myStr)
    listOfResponses = [i for i in listOfResponses if i]
    return listOfResponses

# %%
tf.reset_default_graph()

# Create the placeholders
encoderInputs = [tf.placeholder(tf.int32, shape=(None,)) for i in range(maxEncoderLength)]
decoderLabels = [tf.placeholder(tf.int32, shape=(None,)) for i in range(maxDecoderLength)]
decoderInputs = [tf.placeholder(tf.int32, shape=(None,)) for i in range(maxDecoderLength)]
feedPrevious = tf.placeholder(tf.bool)

# %%
encoderLSTM = tf.contrib.rnn.BasicLSTMCell(lstmUnits, state_is_tuple=True)

# %%
decoderOutputs, decoderFinalState = tf.contrib.legacy_seq2seq.embedding_rnn_seq2seq(encoderInputs, 
                                                                                    decoderInputs, 
                                                                                    encoderLSTM, 
                                                                                    vocabSize, 
                                                                                    vocabSize, 
                                                                                    embeddingDim, 
                                                                                    feed_previous=feedPrevious)

# %%
decoderPrediction = tf.argmax(decoderOutputs, 2)

# %%
lossWeights = [tf.ones_like(l, dtype=tf.float32) for l in decoderLabels]
loss = tf.contrib.legacy_seq2seq.sequence_loss(decoderOutputs, decoderLabels, lossWeights, vocabSize)
optimizer = tf.train.AdamOptimizer(1e-4).minimize(loss)

# %%
sess = tf.Session()
saver = tf.train.Saver()
# If you're loading in a saved model, use the following
#saver.restore(sess, tf.train.latest_checkpoint('models/'))
sess.run(tf.global_variables_initializer())

# %%
# Uploading results to Tensorboard
tf.summary.scalar('Loss', loss)
merged = tf.summary.merge_all()
logdir = "tensorboard/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + "/"
writer = tf.summary.FileWriter(logdir, sess.graph)

# %%
encoderTestStrings = ["whats up bro",
                      "hi",
                      "hey how are you",
                      "eh",
                      "i love you"
                     ]

# %%
zeroVector = np.zeros((1), dtype='int32')

# %%
for i in range(numIterations):

	encoderTrain, decoderTargetTrain, decoderInputTrain = getTrainingBatch(xTrain, yTrain, batchSize, maxEncoderLength)
	feedDict = {encoderInputs[t]: encoderTrain[t] for t in range(maxEncoderLength)}
	feedDict.update({decoderLabels[t]: decoderTargetTrain[t] for t in range(maxDecoderLength)})
	feedDict.update({decoderInputs[t]: decoderInputTrain[t] for t in range(maxDecoderLength)})
	feedDict.update({feedPrevious: False})

	curLoss, _, pred = sess.run([loss, optimizer, decoderPrediction], feed_dict=feedDict)
	
	if (i % 50 == 0):
		print('Current loss:', curLoss, 'at iteration', i)
		summary = sess.run(merged, feed_dict=feedDict)
		writer.add_summary(summary, i)
	if (i % 25 == 0 and i != 0):
		num = randint(0,len(encoderTestStrings) - 1)
		print encoderTestStrings[num]
		inputVector = getTestInput(encoderTestStrings[num], wordList, maxEncoderLength);
		feedDict = {encoderInputs[t]: inputVector[t] for t in range(maxEncoderLength)}
		feedDict.update({decoderLabels[t]: zeroVector for t in range(maxDecoderLength)})
		feedDict.update({decoderInputs[t]: zeroVector for t in range(maxDecoderLength)})
		feedDict.update({feedPrevious: True})
		ids = (sess.run(decoderPrediction, feed_dict=feedDict))
		print idsToSentence(ids, wordList)

	if (i % 10000 == 0 and i != 0):
		savePath = saver.save(sess, "pretrained_seq2seq_new.ckpt", global_step=i)
# Out:
# ('Current loss:', 11.792348, 'at iteration', 0)
# i love you
# []
# ('Current loss:', 11.57716, 'at iteration', 50)
# hi
# []
# hey how are you
# []
# ('Current loss:', 10.117448, 'at iteration', 100)
# hey how are you
# []
# i love you
# []
# ('Current loss:', 8.3583117, 'at iteration', 150)
# i love you
# []
# whats up bro
# []
# ('Current loss:', 6.9422603, 'at iteration', 200)
# whats up bro
# []
# i love you
# []
# ('Current loss:', 5.9378028, 'at iteration', 250)
# hey how are you
# []
# i love you
# []
# ('Current loss:', 5.6092486, 'at iteration', 300)
# hi
# []
# hi
# []
# ('Current loss:', 4.7099671, 'at iteration', 350)
# whats up bro
# []
# whats up bro
# []
# ('Current loss:', 4.6967797, 'at iteration', 400)
# whats up bro
# []
# hi
# []
# ('Current loss:', 3.9221287, 'at iteration', 450)
# i love you
# []
# hi
# []
# ('Current loss:', 3.3816307, 'at iteration', 500)
# eh
# []
# hi
# []
# ('Current loss:', 3.6397047, 'at iteration', 550)
# hey how are you
# []
# hi
# []
# ('Current loss:', 3.7004254, 'at iteration', 600)
# whats up bro
# []
# hi
# []
# ('Current loss:', 3.3836544, 'at iteration', 650)
# eh
# []
# whats up bro
# []
# ('Current loss:', 3.56581, 'at iteration', 700)
# eh
# []
# eh
# []
# ('Current loss:', 3.9451363, 'at iteration', 750)
# i love you
# []
# whats up bro
# []
# ('Current loss:', 3.752033, 'at iteration', 800)
# hi
# []
# eh
# []
# ('Current loss:', 3.5886047, 'at iteration', 850)
# eh
# []
# eh
# []
# ('Current loss:', 3.8381624, 'at iteration', 900)
# i love you
# []
# i love you
# []
# ('Current loss:', 2.6985435, 'at iteration', 950)
# hi
# []
# hey how are you
# []
# ('Current loss:', 2.8045368, 'at iteration', 1000)
# hi
# []
# eh
# []
# ('Current loss:', 3.4264135, 'at iteration', 1050)
# eh
# []
# whats up bro
# []
# ('Current loss:', 3.8561344, 'at iteration', 1100)
# i love you
# []
# eh
# []
# ('Current loss:', 2.9312584, 'at iteration', 1150)
# hi
# []
# eh
# []
# ('Current loss:', 3.0794795, 'at iteration', 1200)
# i love you
# []
# hey how are you
# []
# ('Current loss:', 2.6110971, 'at iteration', 1250)
# hey how are you
# []
# hi
# []
# ('Current loss:', 2.9352829, 'at iteration', 1300)
# hi
# []
# i love you
# []
# ('Current loss:', 3.5761216, 'at iteration', 1350)
# eh
# []
# i love you
# []
# ('Current loss:', 3.1039083, 'at iteration', 1400)
# eh
# []
# eh
# []
# ('Current loss:', 4.2647128, 'at iteration', 1450)
# hi
# []
# hey how are you
# []
# ('Current loss:', 3.5142577, 'at iteration', 1500)
# eh
# []
# hey how are you
# []
# ('Current loss:', 3.2044983, 'at iteration', 1550)
# hey how are you
# []
# i love you
# []
# ('Current loss:', 3.3227634, 'at iteration', 1600)
# i love you
# []
# whats up bro
# []
# ('Current loss:', 3.2450581, 'at iteration', 1650)
# hey how are you
# []
# hey how are you
# []
# ('Current loss:', 2.8802917, 'at iteration', 1700)
# hi
# []
# i love you
# []
# ('Current loss:', 2.1411467, 'at iteration', 1750)
# i love you
# []
# whats up bro
# []
# ('Current loss:', 3.1349285, 'at iteration', 1800)
# hey how are you
# []
# eh
# []
# ('Current loss:', 3.4312277, 'at iteration', 1850)
# whats up bro
# []
# hi
# []
# ('Current loss:', 2.6666481, 'at iteration', 1900)
# eh
# []
# hey how are you
# []
# ('Current loss:', 2.409198, 'at iteration', 1950)
# i love you
# []
# eh
# []
# ('Current loss:', 2.4779215, 'at iteration', 2000)
# hey how are you
# []
# i love you
# []
# ('Current loss:', 2.839637, 'at iteration', 2050)
# whats up bro
# []
# i love you
# []
# ('Current loss:', 2.3974814, 'at iteration', 2100)
# hey how are you
# []
# i love you
# []
# ('Current loss:', 2.9236889, 'at iteration', 2150)
# hi
# []
# i love you
# []
# ('Current loss:', 3.8799064, 'at iteration', 2200)
# hey how are you
# []
# hi
# []
# ('Current loss:', 3.1693351, 'at iteration', 2250)
# eh
# []
# hi
# []
# ('Current loss:', 2.9014618, 'at iteration', 2300)
# whats up bro
# []
# eh
# []
# ('Current loss:', 2.1546004, 'at iteration', 2350)
# hey how are you
# []
# hey how are you
# []
# ('Current loss:', 3.3101082, 'at iteration', 2400)
# hi
# []
# hi
# []
# ('Current loss:', 3.8092883, 'at iteration', 2450)
# hi
# []
# i love you
# []
# ('Current loss:', 2.9632475, 'at iteration', 2500)
# i love you
# []
# whats up bro
# []
# ('Current loss:', 2.3740425, 'at iteration', 2550)
# eh
# []
# hi
# []
# ('Current loss:', 2.9710236, 'at iteration', 2600)
# hey how are you
# []
# hi
# []
# ('Current loss:', 3.0425365, 'at iteration', 2650)
# hey how are you
# []
# eh
# []
# ('Current loss:', 2.8616219, 'at iteration', 2700)
# whats up bro
# []
# eh
# []
# ('Current loss:', 3.2626088, 'at iteration', 2750)
# eh
# []
# i love you
# []
# ('Current loss:', 2.6072619, 'at iteration', 2800)
# whats up bro
# []
# whats up bro
# []
# ('Current loss:', 2.65116, 'at iteration', 2850)
# hey how are you
# []
# whats up bro
# []
# ('Current loss:', 2.7273424, 'at iteration', 2900)
# i love you
# []
# whats up bro
# []
# ('Current loss:', 3.2952216, 'at iteration', 2950)
# eh
# []
# eh
# []
# ('Current loss:', 1.942256, 'at iteration', 3000)
# hey how are you
# []
# eh
# []
# ('Current loss:', 3.0725129, 'at iteration', 3050)
# hi
# []
# whats up bro
# []
# ('Current loss:', 2.3652878, 'at iteration', 3100)
# hi
# []
# hey how are you
# []
# ('Current loss:', 3.148639, 'at iteration', 3150)
# whats up bro
# []
# eh
# []
# ('Current loss:', 2.90962, 'at iteration', 3200)
# i love you
# []
# i love you
# []
# ('Current loss:', 3.0682385, 'at iteration', 3250)
# eh
# []
# hi
# []
# ('Current loss:', 3.5454528, 'at iteration', 3300)
# i love you
# []
# whats up bro
# []
# ('Current loss:', 2.0317652, 'at iteration', 3350)
# whats up bro
# []
# eh
# []
# ('Current loss:', 3.8876393, 'at iteration', 3400)
# whats up bro
# []
# i love you
# []
# ('Current loss:', 3.6226492, 'at iteration', 3450)
# hey how are you
# []
# eh
# []
# ('Current loss:', 2.6221917, 'at iteration', 3500)
# whats up bro
# []
# eh
# []
# ('Current loss:', 2.4897921, 'at iteration', 3550)
# whats up bro
# []
# i love you
# []
# ('Current loss:', 2.9496162, 'at iteration', 3600)
# whats up bro
# []
# eh
# []
# ('Current loss:', 3.3988297, 'at iteration', 3650)
# hey how are you
# []
# i love you
# []
# ('Current loss:', 2.6710331, 'at iteration', 3700)
# whats up bro
# []
# hey how are you
# []
# ('Current loss:', 2.93838, 'at iteration', 3750)
# hi
# []
# whats up bro
# []
# ('Current loss:', 2.5726583, 'at iteration', 3800)
# hey how are you
# []
# i love you
# []
# ('Current loss:', 2.1166017, 'at iteration', 3850)
# hey how are you
# []
# hey how are you
# []
# ('Current loss:', 2.3506691, 'at iteration', 3900)
# whats up bro
# []
# i love you
# []
# ('Current loss:', 2.5136077, 'at iteration', 3950)
# hi
# []
# hey how are you
# []
# ('Current loss:', 2.5368521, 'at iteration', 4000)
# hi
# []
# whats up bro
# ['i ']
# ('Current loss:', 2.3760984, 'at iteration', 4050)
# eh
# []
# whats up bro
# ['i ']
# ('Current loss:', 2.262079, 'at iteration', 4100)
# i love you
# ['i ']
# whats up bro
# []
# ('Current loss:', 1.8786508, 'at iteration', 4150)
# eh
# []
# eh
# []
# ('Current loss:', 2.0990131, 'at iteration', 4200)
# i love you
# []
# eh
# []
# ('Current loss:', 3.2170117, 'at iteration', 4250)
# hey how are you
# []
# i love you
# ['i ']
# ('Current loss:', 2.347899, 'at iteration', 4300)
# whats up bro
# ['i ']
# eh
# []
# ('Current loss:', 2.7051942, 'at iteration', 4350)
# hey how are you
# ['i ']
# hi
# []
# ('Current loss:', 2.4262941, 'at iteration', 4400)
# hi
# []
# hi
# []
# ('Current loss:', 3.0618942, 'at iteration', 4450)
# i love you
# ['i ']
# whats up bro
# ['i ']
# ('Current loss:', 2.4864051, 'at iteration', 4500)
# hi
# []
# whats up bro
# ['i ']
# ('Current loss:', 2.4869473, 'at iteration', 4550)
# eh
# []
# hi
# []
# ('Current loss:', 2.8342772, 'at iteration', 4600)
# hey how are you
# ['i ']
# whats up bro
# ['i ']
# ('Current loss:', 2.2995155, 'at iteration', 4650)
# i love you
# ['i ']
# eh
# []
# ('Current loss:', 2.4126422, 'at iteration', 4700)
# eh
# ['i ']
# hi
# ['i ']
# ('Current loss:', 2.3793638, 'at iteration', 4750)
# hey how are you
# ['i ']
# i love you
# ['i ']
# ('Current loss:', 2.8323154, 'at iteration', 4800)
# whats up bro
# ['i ']
# hey how are you
# ['i ']
# ('Current loss:', 2.3126266, 'at iteration', 4850)
# eh
# []
# i love you
# ['i ']
# ('Current loss:', 2.7677891, 'at iteration', 4900)
# eh
# []
# whats up bro
# ['i ']
# ('Current loss:', 2.6955383, 'at iteration', 4950)
# eh
# ['i ']
# whats up bro
# ['i ']
# ('Current loss:', 2.2338898, 'at iteration', 5000)
# eh
# []
# hi
# ['i ']
# ('Current loss:', 2.7262275, 'at iteration', 5050)
# eh
# []
# hi
# ['i ']
# ('Current loss:', 2.2752378, 'at iteration', 5100)
# eh
# []
# eh
# []
# ('Current loss:', 2.6480815, 'at iteration', 5150)
# hi
# []
# whats up bro
# ['i ']
# ('Current loss:', 2.7529047, 'at iteration', 5200)
# i love you
# ['i ']
# hi
# ['i ']
# ('Current loss:', 2.9091671, 'at iteration', 5250)
# i love you
# ['i ']
# i love you
# ['i ']
# ('Current loss:', 2.2352362, 'at iteration', 5300)
# hey how are you
# ['i ']
# hi
# ['i ']
# ('Current loss:', 2.6384838, 'at iteration', 5350)
# eh
# ['i ']
# whats up bro
# ['i ']
# ('Current loss:', 3.0260906, 'at iteration', 5400)
# hey how are you
# ['i ']
# i love you
# ['i ']
# ('Current loss:', 2.6750174, 'at iteration', 5450)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ['i ']
# ('Current loss:', 2.2419965, 'at iteration', 5500)
# i love you
# ['i ']
# whats up bro
# ['i ']
# ('Current loss:', 2.6137712, 'at iteration', 5550)
# hey how are you
# ['i i ']
# hi
# ['i ']
# ('Current loss:', 2.9715884, 'at iteration', 5600)
# eh
# ['studyyyyyynothing7t ']
# whats up bro
# ['i ']
# ('Current loss:', 2.854564, 'at iteration', 5650)
# i love you
# ['i i ']
# whats up bro
# ['i ']
# ('Current loss:', 2.9975364, 'at iteration', 5700)
# hi
# ['i ']
# hey how are you
# ['i ']
# ('Current loss:', 3.5855446, 'at iteration', 5750)
# hi
# ['i ']
# whats up bro
# ['i ']
# ('Current loss:', 2.6572368, 'at iteration', 5800)
# i love you
# ['i ']
# hey how are you
# ['i ']
# ('Current loss:', 2.6670597, 'at iteration', 5850)
# i love you
# ['i i ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.8245268, 'at iteration', 5900)
# hey how are you
# ['i ']
# i love you
# ['i u ']
# ('Current loss:', 2.0507774, 'at iteration', 5950)
# whats up bro
# ['i ']
# hey how are you
# ['i u ']
# ('Current loss:', 2.4916353, 'at iteration', 6000)
# hey how are you
# ['i u ']
# hi
# ['i ']
# ('Current loss:', 2.1527627, 'at iteration', 6050)
# eh
# ['studyyyyyynothing7t ']
# hi
# ['i studyyyyyynothing7t ']
# ('Current loss:', 3.0003197, 'at iteration', 6100)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ['i ']
# ('Current loss:', 2.7424793, 'at iteration', 6150)
# hey how are you
# ['i i ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2288392, 'at iteration', 6200)
# hey how are you
# ['i i the the the the the the ']
# hi
# ['i studyyyyyynothing7t ']
# ('Current loss:', 2.6666234, 'at iteration', 6250)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6928442, 'at iteration', 6300)
# i love you
# ['i u ']
# i love you
# ['i u ']
# ('Current loss:', 2.7798557, 'at iteration', 6350)
# eh
# ['studyyyyyynothing7t ']
# hi
# ['i studyyyyyynothing7t ']
# ('Current loss:', 2.1359634, 'at iteration', 6400)
# hi
# ['i studyyyyyynothing7t ']
# i love you
# ['i u ']
# ('Current loss:', 2.2178004, 'at iteration', 6450)
# whats up bro
# ['i the the the the el el el el el el el el el el ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4398434, 'at iteration', 6500)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5697563, 'at iteration', 6550)
# i love you
# ['i the the the the the the the el el el el el el el ']
# whats up bro
# ['i the the the the el el el el el el el el el el ']
# ('Current loss:', 2.8092692, 'at iteration', 6600)
# i love you
# ['i u ']
# whats up bro
# ['i the the the the el el el el el el el el el el ']
# ('Current loss:', 2.8637371, 'at iteration', 6650)
# whats up bro
# ['i the the the the the el el el el el el el el el ']
# i love you
# ['i the the the the the the the el el el el el el el ']
# ('Current loss:', 3.0949366, 'at iteration', 6700)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.8857338, 'at iteration', 6750)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ['i the the the the the the the el el el el el el el ']
# ('Current loss:', 2.749532, 'at iteration', 6800)
# i love you
# ['i the the the the the the the el el el el el el el ']
# hey how are you
# ['i the the the the the el el el el el el el el el ']
# ('Current loss:', 2.7365456, 'at iteration', 6850)
# whats up bro
# ['i the the the the el el el el el el el el el el ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.8162225, 'at iteration', 6900)
# i love you
# ['i the the the the the the el el el el el el el el ']
# whats up bro
# ['i the the the the el el el el el el el el el el ']
# ('Current loss:', 2.9610298, 'at iteration', 6950)
# hi
# ['studyyyyyynothing7t ']
# i love you
# ['i the the the the the el el el el el el el el el ']
# ('Current loss:', 3.037885, 'at iteration', 7000)
# whats up bro
# ['i the the the the el el el el el el el el el el ']
# whats up bro
# ['i the the the el el el el el el el el el el el ']
# ('Current loss:', 3.135994, 'at iteration', 7050)
# whats up bro
# ['i the the the a el el el el el el el el el el ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1544466, 'at iteration', 7100)
# i love you
# ['i the the the the the a el el el el el el el el ']
# hey how are you
# ['i the the the the the el el el el el el el el el ']
# ('Current loss:', 2.05392, 'at iteration', 7150)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['i the the the a el el el el el el el el el el ']
# ('Current loss:', 2.9944448, 'at iteration', 7200)
# eh
# ['studyyyyyynothing7t ']
# whats up bro
# ['i the the the el el el el el el el el el el el ']
# ('Current loss:', 2.8312433, 'at iteration', 7250)
# i love you
# ['i the the the the a el el el el el el el el el ']
# hey how are you
# ['i the the the the el el el el el el el el el el ']
# ('Current loss:', 2.7369301, 'at iteration', 7300)
# i love you
# ['i the the the the el el el el el el el el el el ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6532037, 'at iteration', 7350)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3225956, 'at iteration', 7400)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 3.0337613, 'at iteration', 7450)
# i love you
# ['i the the the a el el el el el el el el el el ']
# i love you
# ['i the the the a el el el el el el el el el el ']
# ('Current loss:', 2.6626599, 'at iteration', 7500)
# whats up bro
# ['i the the the el el el el el el el el el el el ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2676103, 'at iteration', 7550)
# whats up bro
# ['i the the the el el el el el el el el el el el ']
# whats up bro
# ['i the the the el el el el el el el el el el el ']
# ('Current loss:', 1.9342822, 'at iteration', 7600)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ['i the the the the el el el el el el el el el el ']
# ('Current loss:', 2.4231899, 'at iteration', 7650)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ['i the the the the el el el el el el el el el el ']
# ('Current loss:', 2.5385487, 'at iteration', 7700)
# hey how are you
# ['i the the the the el el el el el el el el el el ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5241444, 'at iteration', 7750)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4049842, 'at iteration', 7800)
# i love you
# ['i the the the the el el el el el el el el el el ']
# i love you
# ['i the the the the el el el el el el el el el el ']
# ('Current loss:', 2.7542543, 'at iteration', 7850)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6245978, 'at iteration', 7900)
# hey how are you
# ['i the the the the el el el el el el el el el el ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6798279, 'at iteration', 7950)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 3.0803387, 'at iteration', 8000)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ['i the the the a el el el el el el el el el el ']
# ('Current loss:', 2.4920452, 'at iteration', 8050)
# hey how are you
# ['i the the the a el el el el el el el el el el ']
# whats up bro
# ['i the the the el el el el el el el el el el el ']
# ('Current loss:', 2.8674095, 'at iteration', 8100)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ['i the the the a el el el el el el el el el el ']
# ('Current loss:', 2.9565811, 'at iteration', 8150)
# hi
# ['studyyyyyynothing7t ']
# i love you
# ['i the the the a el el el el el el el el el el ']
# ('Current loss:', 2.8021643, 'at iteration', 8200)
# whats up bro
# ['i the the the a el el el el el el el el el el ']
# hey how are you
# ['i the the the the el el el el el el el el el el ']
# ('Current loss:', 2.7956562, 'at iteration', 8250)
# hey how are you
# ['i the the the the el el el el el el el el el el ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.23894, 'at iteration', 8300)
# hi
# ['studyyyyyynothing7t ']
# i love you
# ['i the the the the the el el el el el el el el el ']
# ('Current loss:', 2.4330261, 'at iteration', 8350)
# i love you
# ['i the the the the studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.724591, 'at iteration', 8400)
# whats up bro
# ['i the the the a el el el el el el el el el el ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.925006, 'at iteration', 8450)
# eh
# ['studyyyyyynothing7t ']
# whats up bro
# ['i the the a studyyyyyynothing7t ']
# ('Current loss:', 2.92256, 'at iteration', 8500)
# whats up bro
# ['i the the the a studyyyyyynothing7t ']
# hey how are you
# ['i the the a a el el el el el el el el el el ']
# ('Current loss:', 3.2116477, 'at iteration', 8550)
# hey how are you
# ['i the the a a studyyyyyynothing7t ']
# whats up bro
# ['i the the a a el el el el el el el el el el ']
# ('Current loss:', 2.7323663, 'at iteration', 8600)
# whats up bro
# ['i the the a a el el el el el el el el el el ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.9806812, 'at iteration', 8650)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['i the the a a el el el el el el el el el el ']
# ('Current loss:', 2.4300549, 'at iteration', 8700)
# i love you
# ['i the the a a studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.8467624, 'at iteration', 8750)
# i love you
# ['i the the the the a studyyyyyynothing7t ']
# i love you
# ['i the the the the the a studyyyyyynothing7t ']
# ('Current loss:', 2.8144958, 'at iteration', 8800)
# hey how are you
# ['i the the the the the the studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5651782, 'at iteration', 8850)
# hey how are you
# ['i the the the the the a el el el el el el el el ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 3.0249233, 'at iteration', 8900)
# i love you
# ['i the the a a a studyyyyyynothing7t ']
# i love you
# ['i the the the a a studyyyyyynothing7t ']
# ('Current loss:', 2.5283909, 'at iteration', 8950)
# eh
# ['studyyyyyynothing7t ']
# whats up bro
# ['i the the the a a studyyyyyynothing7t ']
# ('Current loss:', 1.4990748, 'at iteration', 9000)
# hey how are you
# ['i the the the the a a studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4647102, 'at iteration', 9050)
# i love you
# ['i the the the the the a studyyyyyynothing7t ']
# whats up bro
# ['i the the the the the the a studyyyyyynothing7t ']
# ('Current loss:', 2.3570328, 'at iteration', 9100)
# i love you
# ['i the the the the the the the the studyyyyyynothing7t ']
# hey how are you
# ['i the the the the the the the the studyyyyyynothing7t ']
# ('Current loss:', 2.5951374, 'at iteration', 9150)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4159155, 'at iteration', 9200)
# hey how are you
# ['i the the the the the the the the the the studyyyyyynothing7t ']
# whats up bro
# ['i the the the the the the the the the the studyyyyyynothing7t ']
# ('Current loss:', 2.441637, 'at iteration', 9250)
# hey how are you
# ['i the the the the the the a a studyyyyyynothing7t ']
# whats up bro
# ['i the the the a a a studyyyyyynothing7t ']
# ('Current loss:', 3.1058264, 'at iteration', 9300)
# i love you
# ['i the the a a a a studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.9167328, 'at iteration', 9350)
# whats up bro
# ['i the the a a a a a studyyyyyynothing7t ']
# hey how are you
# ['i the the a a a a studyyyyyynothing7t ']
# ('Current loss:', 2.7676342, 'at iteration', 9400)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ['i not ']
# ('Current loss:', 2.3068135, 'at iteration', 9450)
# whats up bro
# ['i the a a a a a studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2585385, 'at iteration', 9500)
# whats up bro
# ['i not ']
# whats up bro
# ['i not ']
# ('Current loss:', 2.536658, 'at iteration', 9550)
# whats up bro
# ['i not ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5707448, 'at iteration', 9600)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ['i not ']
# ('Current loss:', 2.6836202, 'at iteration', 9650)
# whats up bro
# ['i the a a a a a a a studyyyyyynothing7t ']
# i love you
# ['i the the a a a a a a studyyyyyynothing7t ']
# ('Current loss:', 2.8199093, 'at iteration', 9700)
# hey how are you
# ['i not ']
# whats up bro
# ['i the the the a a a a studyyyyyynothing7t ']
# ('Current loss:', 2.5266616, 'at iteration', 9750)
# eh
# ['studyyyyyynothing7t ']
# whats up bro
# ['i the the a a a a a a a studyyyyyynothing7t ']
# ('Current loss:', 3.0578833, 'at iteration', 9800)
# i love you
# ['i the the the a a a a a a a studyyyyyynothing7t ']
# i love you
# ['i not ']
# ('Current loss:', 2.5889442, 'at iteration', 9850)
# hey how are you
# ['i not ']
# i love you
# ['i not ']
# ('Current loss:', 2.5755758, 'at iteration', 9900)
# i love you
# ['i not ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 3.1386578, 'at iteration', 9950)
# i love you
# ['i not ']
# hey how are you
# ['i not ']
# ('Current loss:', 2.0947351, 'at iteration', 10000)
# hi
# ['studyyyyyynothing7t ']
# i love you
# ['i not ']
# ('Current loss:', 3.1134803, 'at iteration', 10050)
# i love you
# ['i not ']
# whats up bro
# ['i not ']
# ('Current loss:', 3.0089331, 'at iteration', 10100)
# i love you
# ['i not ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.951257, 'at iteration', 10150)
# hey how are you
# ['i not ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4678874, 'at iteration', 10200)
# hey how are you
# ['i not ']
# hey how are you
# ['i not ']
# ('Current loss:', 1.7114037, 'at iteration', 10250)
# hey how are you
# ['i not ']
# whats up bro
# ['i not ']
# ('Current loss:', 1.896408, 'at iteration', 10300)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.8673584, 'at iteration', 10350)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1071112, 'at iteration', 10400)
# whats up bro
# ['i not ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5311849, 'at iteration', 10450)
# i love you
# ['i not ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6246376, 'at iteration', 10500)
# hey how are you
# ['i not ']
# i love you
# ['i not ']
# ('Current loss:', 2.7731769, 'at iteration', 10550)
# i love you
# ['i not ']
# hey how are you
# ['i not ']
# ('Current loss:', 2.5545304, 'at iteration', 10600)
# i love you
# ['i not ']
# i love you
# ['i not ']
# ('Current loss:', 2.2908287, 'at iteration', 10650)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ['i not ']
# ('Current loss:', 3.1065893, 'at iteration', 10700)
# whats up bro
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 3.5295849, 'at iteration', 10750)
# hey how are you
# ['i not ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5523632, 'at iteration', 10800)
# whats up bro
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.579819, 'at iteration', 10850)
# hi
# ['studyyyyyynothing7t ']
# i love you
# ['i not ']
# ('Current loss:', 1.9026155, 'at iteration', 10900)
# hey how are you
# ['i not ']
# hey how are you
# ['i not ']
# ('Current loss:', 2.9368713, 'at iteration', 10950)
# i love you
# ['i not ']
# hey how are you
# ['i not ']
# ('Current loss:', 2.2348149, 'at iteration', 11000)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ['i not ']
# ('Current loss:', 2.3174899, 'at iteration', 11050)
# i love you
# ['i not ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6365643, 'at iteration', 11100)
# whats up bro
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.7191918, 'at iteration', 11150)
# i love you
# ['i not ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 3.1359663, 'at iteration', 11200)
# hi
# ['studyyyyyynothing7t ']
# i love you
# ['i not ']
# ('Current loss:', 2.8416834, 'at iteration', 11250)
# hi
# ['studyyyyyynothing7t ']
# i love you
# ['i not ']
# ('Current loss:', 2.2301457, 'at iteration', 11300)
# i love you
# ['i not ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1794732, 'at iteration', 11350)
# hey how are you
# ['i not ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.8411446, 'at iteration', 11400)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ['i not ']
# ('Current loss:', 2.4496529, 'at iteration', 11450)
# i love you
# ['i not ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.736722, 'at iteration', 11500)
# eh
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4103062, 'at iteration', 11550)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ['i not ']
# ('Current loss:', 2.3880756, 'at iteration', 11600)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6282899, 'at iteration', 11650)
# i love you
# ['i not ']
# hey how are you
# ['i not ']
# ('Current loss:', 3.3062136, 'at iteration', 11700)
# hey how are you
# ['i not ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.9012197, 'at iteration', 11750)
# whats up bro
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 3.041352, 'at iteration', 11800)
# hey how are you
# ['i not ']
# i love you
# ['i not ']
# ('Current loss:', 2.4532204, 'at iteration', 11850)
# i love you
# ['i not ']
# hey how are you
# ['i not ']
# ('Current loss:', 2.2958567, 'at iteration', 11900)
# i love you
# ['i not ']
# hey how are you
# ['i not ']
# ('Current loss:', 2.3334451, 'at iteration', 11950)
# hey how are you
# ['i not ']
# i love you
# ['i not ']
# ('Current loss:', 2.1573579, 'at iteration', 12000)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4499009, 'at iteration', 12050)
# whats up bro
# ['studyyyyyynothing7t ']
# i love you
# ['i not ']
# ('Current loss:', 2.6878328, 'at iteration', 12100)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4101334, 'at iteration', 12150)
# i love you
# ["i don't the the the the the the the the the the the the the "]
# hey how are you
# ["i don't the the the the the the the the the the the the the "]
# ('Current loss:', 3.0684793, 'at iteration', 12200)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4437466, 'at iteration', 12250)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4995048, 'at iteration', 12300)
# hey how are you
# ["i don't the the a the the the the the the the the the the "]
# i love you
# ["i don't the a a a a a a the a the the the the "]
# ('Current loss:', 2.278868, 'at iteration', 12350)
# whats up bro
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't a a a a a a a a a a a a a "]
# ('Current loss:', 2.0323172, 'at iteration', 12400)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3219564, 'at iteration', 12450)
# i love you
# ['i have the a a a a a a a a a a a a ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3019483, 'at iteration', 12500)
# whats up bro
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't the the the the the the the the the the the the the "]
# ('Current loss:', 2.3881996, 'at iteration', 12550)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3941786, 'at iteration', 12600)
# whats up bro
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1984193, 'at iteration', 12650)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ['i have the a a a a a a a a a a a a ']
# ('Current loss:', 2.179635, 'at iteration', 12700)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1570237, 'at iteration', 12750)
# hey how are you
# ['i not ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3818872, 'at iteration', 12800)
# hey how are you
# ['i not ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4912717, 'at iteration', 12850)
# i love you
# ["i don't a a a a a a a a a a a a a "]
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4361944, 'at iteration', 12900)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2485168, 'at iteration', 12950)
# i love you
# ["i don't a a a a a a the the the the the the the "]
# hey how are you
# ["i don't a a a a a a a a the a the the the "]
# ('Current loss:', 2.4702342, 'at iteration', 13000)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ["i don't a a a a a a the call "]
# ('Current loss:', 2.1879311, 'at iteration', 13050)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't a the the the the the the the the the the the the "]
# ('Current loss:', 3.2046039, 'at iteration', 13100)
# i love you
# ["i don't a the the the the the the the the the the the the "]
# i love you
# ['i not ']
# ('Current loss:', 2.3360009, 'at iteration', 13150)
# hey how are you
# ['i not ']
# hey how are you
# ["i don't a a a a call "]
# ('Current loss:', 2.5940542, 'at iteration', 13200)
# whats up bro
# ['studyyyyyynothing7t ']
# i love you
# ["i don't a a call "]
# ('Current loss:', 3.3918216, 'at iteration', 13250)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3966293, 'at iteration', 13300)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have "]
# ('Current loss:', 2.3839235, 'at iteration', 13350)
# i love you
# ["i don't a a a call "]
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.9358447, 'at iteration', 13400)
# whats up bro
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6143682, 'at iteration', 13450)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't have the the call "]
# ('Current loss:', 2.8038776, 'at iteration', 13500)
# eh
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5072815, 'at iteration', 13550)
# hey how are you
# ["i don't have the a call "]
# i love you
# ["i don't have "]
# ('Current loss:', 2.3405237, 'at iteration', 13600)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ["i don't a a call "]
# ('Current loss:', 2.6852944, 'at iteration', 13650)
# whats up bro
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3230615, 'at iteration', 13700)
# whats up bro
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1873355, 'at iteration', 13750)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.953315, 'at iteration', 13800)
# i love you
# ["i don't have "]
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5498626, 'at iteration', 13850)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3388927, 'at iteration', 13900)
# whats up bro
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2623069, 'at iteration', 13950)
# whats up bro
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5266821, 'at iteration', 14000)
# whats up bro
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4581649, 'at iteration', 14050)
# hey how are you
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.281198, 'at iteration', 14100)
# eh
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2979441, 'at iteration', 14150)
# whats up bro
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't have the a call "]
# ('Current loss:', 2.0671618, 'at iteration', 14200)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't have the a call "]
# ('Current loss:', 2.5247993, 'at iteration', 14250)
# eh
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.088208, 'at iteration', 14300)
# whats up bro
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 3.1284301, 'at iteration', 14350)
# i love you
# ["i don't have the call "]
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.8693391, 'at iteration', 14400)
# i love you
# ["i don't have the call "]
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.8444723, 'at iteration', 14450)
# i love you
# ["i don't have the call "]
# i love you
# ["i don't have the call "]
# ('Current loss:', 2.4617212, 'at iteration', 14500)
# eh
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4309523, 'at iteration', 14550)
# eh
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.513974, 'at iteration', 14600)
# hey how are you
# ["i don't have the call "]
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.8641323, 'at iteration', 14650)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't have the call "]
# ('Current loss:', 2.348192, 'at iteration', 14700)
# i love you
# ["i don't have the call "]
# i love you
# ["i don't have the call "]
# ('Current loss:', 1.9910046, 'at iteration', 14750)
# whats up bro
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have the call "]
# ('Current loss:', 2.5619261, 'at iteration', 14800)
# hey how are you
# ["i don't have the call "]
# hey how are you
# ["i don't have "]
# ('Current loss:', 1.946298, 'at iteration', 14850)
# hey how are you
# ["i don't have the call "]
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.502264, 'at iteration', 14900)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.8153808, 'at iteration', 14950)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't have the call "]
# ('Current loss:', 2.3321269, 'at iteration', 15000)
# i love you
# ["i don't have the call "]
# i love you
# ["i don't have the call "]
# ('Current loss:', 2.3033564, 'at iteration', 15050)
# eh
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5260618, 'at iteration', 15100)
# hey how are you
# ["i don't have the call "]
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1587555, 'at iteration', 15150)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.9686478, 'at iteration', 15200)
# hey how are you
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have the call "]
# ('Current loss:', 2.8724625, 'at iteration', 15250)
# i love you
# ["i don't have the call "]
# i love you
# ["i don't have the call "]
# ('Current loss:', 2.3201685, 'at iteration', 15300)
# i love you
# ["i don't have the call "]
# hey how are you
# ["i don't have the call "]
# ('Current loss:', 2.482239, 'at iteration', 15350)
# whats up bro
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.7651482, 'at iteration', 15400)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have the call "]
# ('Current loss:', 1.9744358, 'at iteration', 15450)
# hey how are you
# ["i don't have the call "]
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3757551, 'at iteration', 15500)
# i love you
# ["i don't have the call "]
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.7087021, 'at iteration', 15550)
# eh
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2240136, 'at iteration', 15600)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4303999, 'at iteration', 15650)
# hey how are you
# ["i don't have the call "]
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1143227, 'at iteration', 15700)
# whats up bro
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.7431324, 'at iteration', 15750)
# whats up bro
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have "]
# ('Current loss:', 2.2691653, 'at iteration', 15800)
# whats up bro
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have the call "]
# ('Current loss:', 2.3071415, 'at iteration', 15850)
# i love you
# ["i don't have the call "]
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6702321, 'at iteration', 15900)
# whats up bro
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't have the call "]
# ('Current loss:', 2.3969228, 'at iteration', 15950)
# hey how are you
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have the call "]
# ('Current loss:', 3.2797947, 'at iteration', 16000)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.550107, 'at iteration', 16050)
# whats up bro
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have the call "]
# ('Current loss:', 2.7637501, 'at iteration', 16100)
# hey how are you
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have the call "]
# ('Current loss:', 1.8453029, 'at iteration', 16150)
# i love you
# ["i don't have the call "]
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.9162273, 'at iteration', 16200)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.0493302, 'at iteration', 16250)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.9440203, 'at iteration', 16300)
# hey how are you
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.7328272, 'at iteration', 16350)
# hi
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have "]
# ('Current loss:', 2.7144783, 'at iteration', 16400)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.0292079, 'at iteration', 16450)
# whats up bro
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have to a call "]
# ('Current loss:', 2.6685946, 'at iteration', 16500)
# i love you
# ["i don't have "]
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6943207, 'at iteration', 16550)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 3.2810698, 'at iteration', 16600)
# hey how are you
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4264259, 'at iteration', 16650)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.675122, 'at iteration', 16700)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.7715435, 'at iteration', 16750)
# whats up bro
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3895361, 'at iteration', 16800)
# hey how are you
# ["i don't have the call "]
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.9749466, 'at iteration', 16850)
# whats up bro
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5150313, 'at iteration', 16900)
# i love you
# ["i don't have the call "]
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3176677, 'at iteration', 16950)
# whats up bro
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5267017, 'at iteration', 17000)
# i love you
# ["i don't have the call "]
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5110872, 'at iteration', 17050)
# whats up bro
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have the call "]
# ('Current loss:', 3.0951903, 'at iteration', 17100)
# hey how are you
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4686339, 'at iteration', 17150)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.9712414, 'at iteration', 17200)
# whats up bro
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1550062, 'at iteration', 17250)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5942454, 'at iteration', 17300)
# hey how are you
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have the call "]
# ('Current loss:', 2.6540213, 'at iteration', 17350)
# i love you
# ["i don't have the call "]
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.9053161, 'at iteration', 17400)
# i love you
# ["i don't have the call "]
# hey how are you
# ["i don't have the call "]
# ('Current loss:', 2.3734667, 'at iteration', 17450)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.8459558, 'at iteration', 17500)
# whats up bro
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1885388, 'at iteration', 17550)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.369571, 'at iteration', 17600)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3388662, 'at iteration', 17650)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.032532, 'at iteration', 17700)
# hey how are you
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5847647, 'at iteration', 17750)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.8739548, 'at iteration', 17800)
# whats up bro
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4884717, 'at iteration', 17850)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5677507, 'at iteration', 17900)
# whats up bro
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2932549, 'at iteration', 17950)
# i love you
# ["i don't have to a call "]
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3452959, 'at iteration', 18000)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1726229, 'at iteration', 18050)
# hey how are you
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have the call "]
# ('Current loss:', 2.3000591, 'at iteration', 18100)
# i love you
# ["i don't have the call "]
# i love you
# ["i don't have to a call "]
# ('Current loss:', 2.3160586, 'at iteration', 18150)
# hey how are you
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2721775, 'at iteration', 18200)
# eh
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1862938, 'at iteration', 18250)
# i love you
# ["i don't have to a call "]
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.27671, 'at iteration', 18300)
# hey how are you
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have to a call "]
# ('Current loss:', 1.9395508, 'at iteration', 18350)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have to a call "]
# ('Current loss:', 2.5360479, 'at iteration', 18400)
# whats up bro
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.7856796, 'at iteration', 18450)
# hey how are you
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have it "]
# ('Current loss:', 1.9971393, 'at iteration', 18500)
# hi
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have to a call "]
# ('Current loss:', 2.6905231, 'at iteration', 18550)
# i love you
# ["i don't have to a call "]
# i love you
# ["i don't have to a call "]
# ('Current loss:', 2.0897369, 'at iteration', 18600)
# whats up bro
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.5804387, 'at iteration', 18650)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5179551, 'at iteration', 18700)
# i love you
# ["i don't have it "]
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4524078, 'at iteration', 18750)
# i love you
# ["i don't have to a call "]
# whats up bro
# []
# ('Current loss:', 2.8469801, 'at iteration', 18800)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3596284, 'at iteration', 18850)
# hey how are you
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have to a call "]
# ('Current loss:', 2.703408, 'at iteration', 18900)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.7795417, 'at iteration', 18950)
# whats up bro
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2752249, 'at iteration', 19000)
# i love you
# ["i don't have it "]
# i love you
# ["i don't have it "]
# ('Current loss:', 2.1365068, 'at iteration', 19050)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.7219098, 'at iteration', 19100)
# whats up bro
# []
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3530703, 'at iteration', 19150)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.0443947, 'at iteration', 19200)
# hey how are you
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4183095, 'at iteration', 19250)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.9536295, 'at iteration', 19300)
# i love you
# ["i don't have to a call "]
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6954746, 'at iteration', 19350)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.4990029, 'at iteration', 19400)
# hey how are you
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.9343232, 'at iteration', 19450)
# whats up bro
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1350288, 'at iteration', 19500)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have it "]
# ('Current loss:', 2.5241566, 'at iteration', 19550)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.9157153, 'at iteration', 19600)
# whats up bro
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have to a call "]
# ('Current loss:', 1.632017, 'at iteration', 19650)
# hi
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have to a call "]
# ('Current loss:', 1.6163086, 'at iteration', 19700)
# i love you
# ["i don't have to a call "]
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.7757683, 'at iteration', 19750)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.7422223, 'at iteration', 19800)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3016183, 'at iteration', 19850)
# i love you
# ["i don't have to a call "]
# i love you
# ["i don't have to a call "]
# ('Current loss:', 2.3717082, 'at iteration', 19900)
# i love you
# ["i don't have to a call "]
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.7375336, 'at iteration', 19950)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6073055, 'at iteration', 20000)
# i love you
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 3.2137759, 'at iteration', 20050)
# hey how are you
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 3.1958427, 'at iteration', 20100)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.0629466, 'at iteration', 20150)
# eh
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3921251, 'at iteration', 20200)
# eh
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.364794, 'at iteration', 20250)
# i love you
# ["i don't have to a call "]
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6566751, 'at iteration', 20300)
# whats up bro
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6290352, 'at iteration', 20350)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.8075142, 'at iteration', 20400)
# hey how are you
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.8099842, 'at iteration', 20450)
# whats up bro
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1885216, 'at iteration', 20500)
# whats up bro
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.0038326, 'at iteration', 20550)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.7478666, 'at iteration', 20600)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2590115, 'at iteration', 20650)
# whats up bro
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.0777991, 'at iteration', 20700)
# hi
# ['studyyyyyynothing7t ']
# i love you
# ["i don't have to a call "]
# ('Current loss:', 2.0504301, 'at iteration', 20750)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6534474, 'at iteration', 20800)
# hey how are you
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.174279, 'at iteration', 20850)
# hey how are you
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.5646157, 'at iteration', 20900)
# whats up bro
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2250366, 'at iteration', 20950)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.0581839, 'at iteration', 21000)
# hey how are you
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6846352, 'at iteration', 21050)
# hey how are you
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.6392701, 'at iteration', 21100)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.3754973, 'at iteration', 21150)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1166074, 'at iteration', 21200)
# hey how are you
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.8372498, 'at iteration', 21250)
# eh
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.402447, 'at iteration', 21300)
# eh
# ['studyyyyyynothing7t ']
# hey how are you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.244916, 'at iteration', 21350)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.2752068, 'at iteration', 21400)
# eh
# ['studyyyyyynothing7t ']
# i love you
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.555912, 'at iteration', 21450)
# i love you
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ...
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.6948248, 'at iteration', 97250)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.517572, 'at iteration', 97300)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# i love you
# ['studyyyyyynothing7t ', 'is the best of the whole hour ']
# ('Current loss:', 1.7827473, 'at iteration', 97350)
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.8974196, 'at iteration', 97400)
# i love you
# ["i don't want to ", 'is a lot of the same ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.0802135, 'at iteration', 97450)
# eh
# ['studyyyyyynothing7t ', 'keda neik ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.569767, 'at iteration', 97500)
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# i love you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 2.2013175, 'at iteration', 97550)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ', 'is like ']
# ('Current loss:', 1.6387491, 'at iteration', 97600)
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.2038842, 'at iteration', 97650)
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ']
# eh
# ['studyyyyyynothing7t ', 'keda ']
# ('Current loss:', 1.6186496, 'at iteration', 97700)
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 1.7169561, 'at iteration', 97750)
# i love you
# ["i don't want to do ", 'is a lot of ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ']
# ('Current loss:', 1.7852408, 'at iteration', 97800)
# i love you
# ["i don't want to do ", 'is a lot of ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1253977, 'at iteration', 97850)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ']
# ('Current loss:', 1.6074886, 'at iteration', 97900)
# i love you
# ["i don't want to do ", 'is a lot of ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 2.0331705, 'at iteration', 97950)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.125869, 'at iteration', 98000)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ']
# ('Current loss:', 1.5033174, 'at iteration', 98050)
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world is like ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.0797793, 'at iteration', 98100)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 1.7393541, 'at iteration', 98150)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.687055, 'at iteration', 98200)
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.4374658, 'at iteration', 98250)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# hey how are you
# ['studyyyyyynothing7t ', 'is a lot of the one is like ']
# ('Current loss:', 1.5566977, 'at iteration', 98300)
# whats up bro
# ['studyyyyyynothing7t ', 'is the exam is a lot of the world ']
# i love you
# ["i don't want to do ", 'is a lot of the same ']
# ('Current loss:', 2.1166031, 'at iteration', 98350)
# whats up bro
# ['studyyyyyynothing7t ', 'is the exam is a lot of stuff ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 1.9838672, 'at iteration', 98400)
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the exam is a lot of the world ']
# ('Current loss:', 1.7177639, 'at iteration', 98450)
# whats up bro
# ['studyyyyyynothing7t ', 'is the exam is a lot of the world ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the exam is a lot of the world ']
# ('Current loss:', 1.9305729, 'at iteration', 98500)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.7596182, 'at iteration', 98550)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ', 'is like ']
# ('Current loss:', 1.7898816, 'at iteration', 98600)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.4984475, 'at iteration', 98650)
# i love you
# ["i don't want to do ", 'is a lot of ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world is like ']
# ('Current loss:', 1.6884388, 'at iteration', 98700)
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world is like ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.3862005, 'at iteration', 98750)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 2.0087316, 'at iteration', 98800)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# i love you
# ["i don't want to do ", 'is a lot of ']
# ('Current loss:', 1.6804949, 'at iteration', 98850)
# i love you
# ["i don't want to do ", 'is a lot of ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 1.7033762, 'at iteration', 98900)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.569244, 'at iteration', 98950)
# i love you
# ["i don't want to do ", 'is a lot of ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 1.6348549, 'at iteration', 99000)
# i love you
# ["i don't want to do ", 'is a lot of ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world is like ']
# ('Current loss:', 2.2150776, 'at iteration', 99050)
# whats up bro
# ['studyyyyyynothing7t ', 'is the exam is a lot of the world ']
# eh
# ['studyyyyyynothing7t el a5bar el studyyyyyynothing7t ']
# ('Current loss:', 1.7704648, 'at iteration', 99100)
# eh
# ['studyyyyyynothing7t el a5bar el studyyyyyynothing7t ']
# i love you
# ["i don't want to do ", 'is a lot of ']
# ('Current loss:', 1.6178893, 'at iteration', 99150)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 1.421394, 'at iteration', 99200)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.4014964, 'at iteration', 99250)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world is better ']
# ('Current loss:', 1.9807702, 'at iteration', 99300)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.5127586, 'at iteration', 99350)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world is the same ']
# ('Current loss:', 1.8211712, 'at iteration', 99400)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.6010319, 'at iteration', 99450)
# i love you
# ["i don't want to do it ", 'is a lot ']
# hey how are you
# ["i don't want to do ", 'is a lot of ']
# ('Current loss:', 1.5530981, 'at iteration', 99500)
# eh
# ['studyyyyyynothing7t el 7asal ']
# i love you
# ["i don't want to do ", 'is a lot of ']
# ('Current loss:', 2.1600294, 'at iteration', 99550)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.1829184, 'at iteration', 99600)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ']
# ('Current loss:', 1.6921192, 'at iteration', 99650)
# i love you
# ["i don't want to do ", 'is a lot of ']
# i love you
# ["i don't want to do ", 'is a lot of ']
# ('Current loss:', 1.7093438, 'at iteration', 99700)
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world is better ']
# i love you
# ["i don't want to do it ", 'is a lot of ']
# ('Current loss:', 1.705958, 'at iteration', 99750)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.7623945, 'at iteration', 99800)
# eh
# ['studyyyyyynothing7t ', 'keda neik ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 1.6768175, 'at iteration', 99850)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.487009, 'at iteration', 99900)
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world is better ']
# ('Current loss:', 1.6536084, 'at iteration', 99950)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world is better ']
# ('Current loss:', 1.829277, 'at iteration', 100000)
# i love you
# ["i don't want to do it ", 'is a lot of ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.8004459, 'at iteration', 100050)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.9620519, 'at iteration', 100100)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.627694, 'at iteration', 100150)
# hi
# ['studyyyyyynothing7t ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the exam is a lot of the world ']
# ('Current loss:', 1.4715137, 'at iteration', 100200)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.8721842, 'at iteration', 100250)
# hi
# ['studyyyyyynothing7t ']
# hey how are you
# ["i don't want to ", 'to u ', 'is a email ']
# ('Current loss:', 1.5414333, 'at iteration', 100300)
# whats up bro
# ['studyyyyyynothing7t ', 'is the exam is a lot of the world ']
# eh
# ['studyyyyyynothing7t el a5bar el studyyyyyynothing7t ']
# ('Current loss:', 1.9477507, 'at iteration', 100350)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ', 'keda neik ']
# ('Current loss:', 1.29482, 'at iteration', 100400)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ', 'keda neik ']
# ('Current loss:', 1.5842768, 'at iteration', 100450)
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 2.1985242, 'at iteration', 100500)
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ']
# ('Current loss:', 2.1932576, 'at iteration', 100550)
# i love you
# ["i don't want to do it ", 'is a lot of ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.3803054, 'at iteration', 100600)
# i love you
# ["i don't want to ", 'is a lot of the same ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 1.9436556, 'at iteration', 100650)
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 1.7859665, 'at iteration', 100700)
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.9309441, 'at iteration', 100750)
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world is the same ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.4296144, 'at iteration', 100800)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ', 'is the same ']
# ('Current loss:', 1.9490055, 'at iteration', 100850)
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ']
# whats up bro
# ['studyyyyyynothing7t ', 'is the exam is a lot of the world ']
# ('Current loss:', 1.9297196, 'at iteration', 100900)
# hey how are you
# ["i don't want to ", 'to u ', 'to be like ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.8678288, 'at iteration', 100950)
# whats up bro
# ['studyyyyyynothing7t ', 'is the exam is a lot of the world ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.6978554, 'at iteration', 101000)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 2.2342737, 'at iteration', 101050)
# i love you
# ["i don't want to do ", 'is a lot of ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 2.1924174, 'at iteration', 101100)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 1.7951654, 'at iteration', 101150)
# i love you
# ["i don't want to do ", 'is a lot of the same ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 1.7779145, 'at iteration', 101200)
# i love you
# ["i don't want to do ", 'is a lot of ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.9819225, 'at iteration', 101250)
# i love you
# ["i don't want to do ", 'is a lot of ']
# i love you
# ["i don't want to do it ", 'is a lot of ']
# ('Current loss:', 1.5530144, 'at iteration', 101300)
# hi
# ['studyyyyyynothing7t ']
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# ('Current loss:', 2.03211, 'at iteration', 101350)
# hi
# ['studyyyyyynothing7t ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.856892, 'at iteration', 101400)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# hey how are you
# ["i don't want to ", 'is a lot of the same ']
# ('Current loss:', 1.4272103, 'at iteration', 101450)
# whats up bro
# ['studyyyyyynothing7t ', 'is the exam is a lot of the world ']
# hi
# ['studyyyyyynothing7t ']
# ('Current loss:', 1.9390143, 'at iteration', 101500)
# eh
# ['studyyyyyynothing7t ', 'keda neik ']
# eh
# ['studyyyyyynothing7t ', 'keda neik ']
# ('Current loss:', 1.6422011, 'at iteration', 101550)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# eh
# ['studyyyyyynothing7t ', 'keda neik ']
# ('Current loss:', 1.3415073, 'at iteration', 101600)
# eh
# ['studyyyyyynothing7t ', 'keda neik :d ']
# i love you
# ["i don't want to do ", 'is a lot of the same ']
# ('Current loss:', 1.3345226, 'at iteration', 101650)
# whats up bro
# ['studyyyyyynothing7t ', 'is the same of the world ', 'is it ']
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-34-f90fe33675ad> in <module>()
#       7         feedDict.update({feedPrevious: False})
#       8
# ----> 9         curLoss, _, pred = sess.run([loss, optimizer, decoderPrediction], feed_dict=feedDict)
#      10
#      11         if (i % 50 == 0):
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
savePath = saver.save(sess, "pretrained_seq2seq.ckpt", global_step=i)
